# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# In this lab you will:
#
# - Use concatenation to combine DataFrames
# - Determine which type of join is preferred for two tables of data and a task
# - Use different types of joins to merge dataframes
#
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combine = [df1, df2, df3]
conbined_df = pd.concat(combine)
conbined_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting join conditions with concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` function to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = pd.concat([df1, df4], axis = 1 , join = 'inner')
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results contain only the rows with indexes that exist in both tables -- rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `pd.concat()` function in pandas to join DataFrames together -- these are just a few of the most common examples pulled from the pandas documentation on the subject. For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Load data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the [Kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table -- but not all -- correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame. You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the DataFrames you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the `.head()` of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index('card_id', inplace=True)
dust_df.set_index('card_id', inplace=True)
entourages_df.set_index('card_id', inplace=True)
mechanics_df.set_index('card_id', inplace=True)
play_requirements_df.set_index('card_id', inplace=True)

# %%
cards_df.head()
# Out:
#            player_class    type                name      set  \
# card_id
# KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a         DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2         DRUID  MINION  Druid of the Flame      BRM
# AT_132          NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                 NaN   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                    NaN  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN        NaN          NaN
# NEW1_008a      NaN        NaN          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                                NaN    NaN
# NEW1_008a                                                 NaN    NaN
# BRM_010t2                                                 NaN  BEAST
# AT_132      It's like putting racing stripes and a giant s...    NaN
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...    NaN
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07         NaN                NaN                  NaN     NaN
# NEW1_008a          NaN                NaN                  NaN     NaN
# BRM_010t2          NaN                NaN                  NaN     NaN
# AT_132             NaN                NaN                  NaN     NaN
# OG_141             NaN                NaN                  NaN     NaN
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
dust_df.head()
# Out:
#                       action  cost
# card_id
# BRM_010t2    CRAFTING_NORMAL    40
# BRM_010t2    CRAFTING_GOLDEN   400
# BRM_010t2  DISENCHANT_NORMAL     5
# BRM_010t2  DISENCHANT_GOLDEN    50
# AT_132       CRAFTING_NORMAL  1600

# %%
entourages_df.head()
# Out:
#            entourage_card_id
# card_id
# KAR_A10_22        KAR_A10_09
# KAR_A10_22        KAR_A10_02
# KAR_A10_22        KAR_A10_08
# KAR_A10_22        KAR_A10_04
# KAR_A10_22        KAR_A10_05

# %%
mechanics_df.head()
# Out:
#                      mechanic
# card_id
# AT_132              BATTLECRY
# GVG_011a  TAG_ONE_TURN_EFFECT
# EX1_583             BATTLECRY
# LOE_007t            EVIL_GLOW
# LOE_007t   ImmuneToSpellpower

# %%
play_requirements_df.head()
# Out:
#                      play_requirement  value
# card_id
# KARA_00_07       REQ_NUM_MINION_SLOTS      1
# PRO_001a         REQ_NUM_MINION_SLOTS      1
# NAX1_01          REQ_NUM_MINION_SLOTS      1
# DS1h_292_H1           REQ_STEADY_SHOT      0
# DS1h_292_H1  REQ_MINION_OR_ENEMY_HERO      0

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are four different kinds of joins, which can best be visualized with Venn diagrams:
#
# <img src='images/Image_198_joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table. The left table is the table you are working with, and the right table is the table you want to join to the table you are working with. You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df, how = 'inner')
cards_with_mechanics_df
# Out:
#         player_class    type                    name      set  \
# card_id
# AT_002          MAGE   SPELL                  Effigy      TGT
# AT_005t      NEUTRAL  MINION                    Boar      TGT
# AT_006          MAGE  MINION        Dalaran Aspirant      TGT
# AT_007          MAGE  MINION            Spellslinger      TGT
# AT_009          MAGE  MINION                  Rhonin      TGT
# ...              ...     ...                     ...      ...
# XXX_105      NEUTRAL   SPELL        Add 8 to Health.    CHEAT
# XXX_107      NEUTRAL   SPELL         Set Health to 1    CHEAT
# XXX_110      NEUTRAL  MINION  Yogg-Saron Test (Auto)    CHEAT
# hexfrog      NEUTRAL  MINION                    Frog     CORE
# tt_010          MAGE   SPELL             Spellbender  EXPERT1
#
#                                                       text  cost  attack  \
# card_id
# AT_002   <b>Secret:</b> When a friendly minion dies, su...   3.0     NaN
# AT_005t                                      <b>Charge</b>   3.0     4.0
# AT_006        <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0     3.0
# AT_007   <b>Battlecry:</b> Add a random spell to each p...   3.0     3.0
# AT_009   <b>Deathrattle:</b> Add 3 copies of Arcane Mis...   8.0     7.0
# ...                                                    ...   ...     ...
# XXX_105  Adds 8 health to a damaged character. Does NOT...   0.0     NaN
# XXX_107  Set a character's health to 1, and remove all ...   0.0     NaN
# XXX_110  <b>Battlecry:</b> Cast 30 random spells <i>(ta...   0.0     7.0
# hexfrog                                       <b>Taunt</b>   0.0     0.0
# tt_010   <b>Secret:</b> When an enemy casts a spell on ...   3.0     NaN
#
#          health     rarity  collectible  \
# card_id
# AT_002      NaN       RARE          1.0
# AT_005t     2.0        NaN          NaN
# AT_006      5.0     COMMON          1.0
# AT_007      4.0     COMMON          1.0
# AT_009      7.0  LEGENDARY          1.0
# ...         ...        ...          ...
# XXX_105     NaN     COMMON          NaN
# XXX_107     NaN     COMMON          NaN
# XXX_110     5.0  LEGENDARY          NaN
# hexfrog     1.0     COMMON          NaN
# tt_010      NaN       EPIC          1.0
#
#                                                     flavor   race how_to_earn  \
# card_id
# AT_002                                  Burning man, brah.    NaN         NaN
# AT_005t                                                NaN  BEAST         NaN
# AT_006    Is he aspiring or inspiring?  Make up your mind!    NaN         NaN
# AT_007   Does he sling spells, or do his spells linger ...    NaN         NaN
# AT_009                              A masterless shamurai.    NaN         NaN
# ...                                                    ...    ...         ...
# XXX_105                                                NaN    NaN         NaN
# XXX_107                                                NaN    NaN         NaN
# XXX_110                                                NaN    NaN         NaN
# hexfrog                                                NaN  BEAST         NaN
# tt_010   While it's fun to intercept enemy lightning bo...    NaN         NaN
#
#         how_to_earn_golden targeting_arrow_text faction  durability  \
# card_id
# AT_002                 NaN                  NaN     NaN         NaN
# AT_005t                NaN                  NaN     NaN         NaN
# AT_006                 NaN                  NaN     NaN         NaN
# AT_007                 NaN                  NaN     NaN         NaN
# AT_009                 NaN                  NaN     NaN         NaN
# ...                    ...                  ...     ...         ...
# XXX_105                NaN                  NaN     NaN         NaN
# XXX_107                NaN                  NaN     NaN         NaN
# XXX_110                NaN                  NaN     NaN         NaN
# hexfrog                NaN                  NaN     NaN         NaN
# tt_010                 NaN                  NaN     NaN         NaN
#
#                    mechanic
# card_id
# AT_002               SECRET
# AT_005t              CHARGE
# AT_006              INSPIRE
# AT_007            BATTLECRY
# AT_009          DEATHRATTLE
# ...                     ...
# XXX_105  ImmuneToSpellpower
# XXX_107  ImmuneToSpellpower
# XXX_110           BATTLECRY
# hexfrog               TAUNT
# tt_010               SECRET
#
# [1079 rows x 18 columns]

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, contains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
# We only look at the records that are in both of the dataframes because we are joining the inner portion of the dataframes

# %% [markdown]
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join(play_requirements_df, how = 'left')
left_join_df
#left join adds the matching entries from left and right join to the left dataframe
# Out:
#         player_class    type                    name      set  \
# card_id
# AT_002          MAGE   SPELL                  Effigy      TGT
# AT_005t      NEUTRAL  MINION                    Boar      TGT
# AT_006          MAGE  MINION        Dalaran Aspirant      TGT
# AT_007          MAGE  MINION            Spellslinger      TGT
# AT_009          MAGE  MINION                  Rhonin      TGT
# ...              ...     ...                     ...      ...
# XXX_105      NEUTRAL   SPELL        Add 8 to Health.    CHEAT
# XXX_107      NEUTRAL   SPELL         Set Health to 1    CHEAT
# XXX_110      NEUTRAL  MINION  Yogg-Saron Test (Auto)    CHEAT
# hexfrog      NEUTRAL  MINION                    Frog     CORE
# tt_010          MAGE   SPELL             Spellbender  EXPERT1
#
#                                                       text  cost  attack  \
# card_id
# AT_002   <b>Secret:</b> When a friendly minion dies, su...   3.0     NaN
# AT_005t                                      <b>Charge</b>   3.0     4.0
# AT_006        <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0     3.0
# AT_007   <b>Battlecry:</b> Add a random spell to each p...   3.0     3.0
# AT_009   <b>Deathrattle:</b> Add 3 copies of Arcane Mis...   8.0     7.0
# ...                                                    ...   ...     ...
# XXX_105  Adds 8 health to a damaged character. Does NOT...   0.0     NaN
# XXX_107  Set a character's health to 1, and remove all ...   0.0     NaN
# XXX_110  <b>Battlecry:</b> Cast 30 random spells <i>(ta...   0.0     7.0
# hexfrog                                       <b>Taunt</b>   0.0     0.0
# tt_010   <b>Secret:</b> When an enemy casts a spell on ...   3.0     NaN
#
#          health     rarity  collectible  \
# card_id
# AT_002      NaN       RARE          1.0
# AT_005t     2.0        NaN          NaN
# AT_006      5.0     COMMON          1.0
# AT_007      4.0     COMMON          1.0
# AT_009      7.0  LEGENDARY          1.0
# ...         ...        ...          ...
# XXX_105     NaN     COMMON          NaN
# XXX_107     NaN     COMMON          NaN
# XXX_110     5.0  LEGENDARY          NaN
# hexfrog     1.0     COMMON          NaN
# tt_010      NaN       EPIC          1.0
#
#                                                     flavor   race how_to_earn  \
# card_id
# AT_002                                  Burning man, brah.    NaN         NaN
# AT_005t                                                NaN  BEAST         NaN
# AT_006    Is he aspiring or inspiring?  Make up your mind!    NaN         NaN
# AT_007   Does he sling spells, or do his spells linger ...    NaN         NaN
# AT_009                              A masterless shamurai.    NaN         NaN
# ...                                                    ...    ...         ...
# XXX_105                                                NaN    NaN         NaN
# XXX_107                                                NaN    NaN         NaN
# XXX_110                                                NaN    NaN         NaN
# hexfrog                                                NaN  BEAST         NaN
# tt_010   While it's fun to intercept enemy lightning bo...    NaN         NaN
#
#         how_to_earn_golden targeting_arrow_text faction  durability  \
# card_id
# AT_002                 NaN                  NaN     NaN         NaN
# AT_005t                NaN                  NaN     NaN         NaN
# AT_006                 NaN                  NaN     NaN         NaN
# AT_007                 NaN                  NaN     NaN         NaN
# AT_009                 NaN                  NaN     NaN         NaN
# ...                    ...                  ...     ...         ...
# XXX_105                NaN                  NaN     NaN         NaN
# XXX_107                NaN                  NaN     NaN         NaN
# XXX_110                NaN                  NaN     NaN         NaN
# hexfrog                NaN                  NaN     NaN         NaN
# tt_010                 NaN                  NaN     NaN         NaN
#
#                    mechanic    play_requirement  value
# card_id
# AT_002               SECRET                 NaN    NaN
# AT_005t              CHARGE                 NaN    NaN
# AT_006              INSPIRE                 NaN    NaN
# AT_007            BATTLECRY                 NaN    NaN
# AT_009          DEATHRATTLE                 NaN    NaN
# ...                     ...                 ...    ...
# XXX_105  ImmuneToSpellpower  REQ_TARGET_TO_PLAY    0.0
# XXX_107  ImmuneToSpellpower  REQ_TARGET_TO_PLAY    0.0
# XXX_110           BATTLECRY                 NaN    NaN
# hexfrog               TAUNT                 NaN    NaN
# tt_010               SECRET                 NaN    NaN
#
# [1226 rows x 20 columns]

# %%
right_join_df = cards_with_mechanics_df.join(play_requirements_df, how = 'right')
right_join_df
# Out:
#         player_class   type              name    set  \
# card_id
# AT_001           NaN    NaN               NaN    NaN
# AT_001           NaN    NaN               NaN    NaN
# AT_004           NaN    NaN               NaN    NaN
# AT_004           NaN    NaN               NaN    NaN
# AT_005           NaN    NaN               NaN    NaN
# ...              ...    ...               ...    ...
# XXX_104      NEUTRAL  SPELL  Add 4 to Health.  CHEAT
# XXX_105      NEUTRAL  SPELL  Add 8 to Health.  CHEAT
# XXX_107      NEUTRAL  SPELL   Set Health to 1  CHEAT
# XXX_112          NaN    NaN               NaN    NaN
# XXX_112          NaN    NaN               NaN    NaN
#
#                                                       text  cost  attack  \
# card_id
# AT_001                                                 NaN   NaN     NaN
# AT_001                                                 NaN   NaN     NaN
# AT_004                                                 NaN   NaN     NaN
# AT_004                                                 NaN   NaN     NaN
# AT_005                                                 NaN   NaN     NaN
# ...                                                    ...   ...     ...
# XXX_104  Adds 4 health to a damaged character. Does NOT...   0.0     NaN
# XXX_105  Adds 8 health to a damaged character. Does NOT...   0.0     NaN
# XXX_107  Set a character's health to 1, and remove all ...   0.0     NaN
# XXX_112                                                NaN   NaN     NaN
# XXX_112                                                NaN   NaN     NaN
#
#          health  rarity  collectible flavor race how_to_earn  \
# card_id
# AT_001      NaN     NaN          NaN    NaN  NaN         NaN
# AT_001      NaN     NaN          NaN    NaN  NaN         NaN
# AT_004      NaN     NaN          NaN    NaN  NaN         NaN
# AT_004      NaN     NaN          NaN    NaN  NaN         NaN
# AT_005      NaN     NaN          NaN    NaN  NaN         NaN
# ...         ...     ...          ...    ...  ...         ...
# XXX_104     NaN  COMMON          NaN    NaN  NaN         NaN
# XXX_105     NaN  COMMON          NaN    NaN  NaN         NaN
# XXX_107     NaN  COMMON          NaN    NaN  NaN         NaN
# XXX_112     NaN     NaN          NaN    NaN  NaN         NaN
# XXX_112     NaN     NaN          NaN    NaN  NaN         NaN
#
#         how_to_earn_golden targeting_arrow_text faction  durability  \
# card_id
# AT_001                 NaN                  NaN     NaN         NaN
# AT_001                 NaN                  NaN     NaN         NaN
# AT_004                 NaN                  NaN     NaN         NaN
# AT_004                 NaN                  NaN     NaN         NaN
# AT_005                 NaN                  NaN     NaN         NaN
# ...                    ...                  ...     ...         ...
# XXX_104                NaN                  NaN     NaN         NaN
# XXX_105                NaN                  NaN     NaN         NaN
# XXX_107                NaN                  NaN     NaN         NaN
# XXX_112                NaN                  NaN     NaN         NaN
# XXX_112                NaN                  NaN     NaN         NaN
#
#                    mechanic    play_requirement  value
# card_id
# AT_001                  NaN  REQ_TARGET_TO_PLAY      0
# AT_001                  NaN   REQ_MINION_TARGET      0
# AT_004                  NaN  REQ_TARGET_TO_PLAY      0
# AT_004                  NaN   REQ_MINION_TARGET      0
# AT_005                  NaN  REQ_TARGET_TO_PLAY      0
# ...                     ...                 ...    ...
# XXX_104  ImmuneToSpellpower  REQ_TARGET_TO_PLAY      0
# XXX_105  ImmuneToSpellpower  REQ_TARGET_TO_PLAY      0
# XXX_107  ImmuneToSpellpower  REQ_TARGET_TO_PLAY      0
# XXX_112                 NaN  REQ_TARGET_TO_PLAY      0
# XXX_112                 NaN     REQ_HERO_TARGET      0
#
# [793 rows x 20 columns]

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________

# %% [markdown]
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = cards_df.join(dust_df, how = 'outer', rsuffix = '_dust')
outer_join_df
# Out:
#         player_class    type         name      set  \
# card_id
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_002          MAGE   SPELL       Effigy      TGT
# ...              ...     ...          ...      ...
# tt_010          MAGE   SPELL  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
#
#                                                       text  cost  attack  \
# card_id
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_002   <b>Secret:</b> When a friendly minion dies, su...   3.0     NaN
# ...                                                    ...   ...     ...
# tt_010   <b>Secret:</b> When an enemy casts a spell on ...   3.0     NaN
# tt_010a                                                NaN   1.0     1.0
# tt_010a                                                NaN   1.0     1.0
# tt_010a                                                NaN   1.0     1.0
# tt_010a                                                NaN   1.0     1.0
#
#          health  rarity  collectible  \
# card_id
# AT_001      NaN  COMMON          1.0
# AT_001      NaN  COMMON          1.0
# AT_001      NaN  COMMON          1.0
# AT_001      NaN  COMMON          1.0
# AT_002      NaN    RARE          1.0
# ...         ...     ...          ...
# tt_010      NaN    EPIC          1.0
# tt_010a     3.0    EPIC          NaN
# tt_010a     3.0    EPIC          NaN
# tt_010a     3.0    EPIC          NaN
# tt_010a     3.0    EPIC          NaN
#
#                                                     flavor race how_to_earn  \
# card_id
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_002                                  Burning man, brah.  NaN         NaN
# ...                                                    ...  ...         ...
# tt_010   While it's fun to intercept enemy lightning bo...  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
#
#         how_to_earn_golden targeting_arrow_text faction  durability  \
# card_id
# AT_001                 NaN                  NaN     NaN         NaN
# AT_001                 NaN                  NaN     NaN         NaN
# AT_001                 NaN                  NaN     NaN         NaN
# AT_001                 NaN                  NaN     NaN         NaN
# AT_002                 NaN                  NaN     NaN         NaN
# ...                    ...                  ...     ...         ...
# tt_010                 NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
#
#                     action  cost_dust
# card_id
# AT_001     CRAFTING_NORMAL       40.0
# AT_001     CRAFTING_GOLDEN      400.0
# AT_001   DISENCHANT_NORMAL        5.0
# AT_001   DISENCHANT_GOLDEN       50.0
# AT_002     CRAFTING_NORMAL      100.0
# ...                    ...        ...
# tt_010   DISENCHANT_GOLDEN      400.0
# tt_010a    CRAFTING_NORMAL      400.0
# tt_010a    CRAFTING_GOLDEN     1600.0
# tt_010a  DISENCHANT_NORMAL      100.0
# tt_010a  DISENCHANT_GOLDEN      400.0
#
# [5849 rows x 19 columns]

# %%
outer_join_df.drop_duplicates(keep=False, subset=['name'])
# Out:
#               player_class         type                             name  \
# card_id
# AT_006e               MAGE  ENCHANTMENT                 Power of Dalaran
# AT_011e            NEUTRAL  ENCHANTMENT                 Light's Blessing
# AT_014e             PRIEST  ENCHANTMENT                    Shadowfiended
# AT_016e             PRIEST  ENCHANTMENT                         Confused
# AT_017e            NEUTRAL  ENCHANTMENT               Twilight's Embrace
# ...                    ...          ...                              ...
# XXX_115            NEUTRAL        SPELL             Destroy Played Cards
# XXX_115e           NEUTRAL  ENCHANTMENT  Destroy Played Card Enchantment
# XXX_999_Crash      NEUTRAL        SPELL                 Crash the server
# hexfrog            NEUTRAL       MINION                             Frog
# tt_004o            NEUTRAL  ENCHANTMENT                      Cannibalize
#
#                    set                                             text  cost  \
# card_id
# AT_006e            TGT                          Increased Spell Damage.   NaN
# AT_011e            TGT                                Increased Attack.   NaN
# AT_014e            TGT                                  Costs (1) less.   NaN
# AT_016e            TGT                       Swapped Attack and Health.   NaN
# AT_017e            TGT                      +1 Attack and <b>Taunt</b>.   NaN
# ...                ...                                              ...   ...
# XXX_115          CHEAT  Whenever a player summons a minion, destroy it.   0.0
# XXX_115e         CHEAT  Whenever a player summons a minion, destroy it.   NaN
# XXX_999_Crash    CHEAT                                 Crash the server   0.0
# hexfrog           CORE                                     <b>Taunt</b>   0.0
# tt_004o        EXPERT1                                Increased Attack.   NaN
#
#                attack  health  rarity  collectible flavor   race how_to_earn  \
# card_id
# AT_006e           NaN     NaN     NaN          NaN    NaN    NaN         NaN
# AT_011e           NaN     NaN     NaN          NaN    NaN    NaN         NaN
# AT_014e           NaN     NaN     NaN          NaN    NaN    NaN         NaN
# AT_016e           NaN     NaN     NaN          NaN    NaN    NaN         NaN
# AT_017e           NaN     NaN     NaN          NaN    NaN    NaN         NaN
# ...               ...     ...     ...          ...    ...    ...         ...
# XXX_115           NaN     NaN  COMMON          NaN    NaN    NaN         NaN
# XXX_115e          NaN     NaN  COMMON          NaN    NaN    NaN         NaN
# XXX_999_Crash     NaN     NaN  COMMON          NaN    NaN    NaN         NaN
# hexfrog           0.0     1.0  COMMON          NaN    NaN  BEAST         NaN
# tt_004o           NaN     NaN     NaN          NaN    NaN    NaN         NaN
#
#               how_to_earn_golden targeting_arrow_text faction  durability  \
# card_id
# AT_006e                      NaN                  NaN     NaN         NaN
# AT_011e                      NaN                  NaN     NaN         NaN
# AT_014e                      NaN                  NaN     NaN         NaN
# AT_016e                      NaN                  NaN     NaN         NaN
# AT_017e                      NaN                  NaN     NaN         NaN
# ...                          ...                  ...     ...         ...
# XXX_115                      NaN                  NaN     NaN         NaN
# XXX_115e                     NaN                  NaN     NaN         NaN
# XXX_999_Crash                NaN                  NaN     NaN         NaN
# hexfrog                      NaN                  NaN     NaN         NaN
# tt_004o                      NaN                  NaN     NaN         NaN
#
#               action  cost_dust
# card_id
# AT_006e          NaN        NaN
# AT_011e          NaN        NaN
# AT_014e          NaN        NaN
# AT_016e          NaN        NaN
# AT_017e          NaN        NaN
# ...              ...        ...
# XXX_115          NaN        NaN
# XXX_115e         NaN        NaN
# XXX_999_Crash    NaN        NaN
# hexfrog          NaN        NaN
# tt_004o          NaN        NaN
#
# [930 rows x 19 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)

# %%
def unique_set(df) :
    df = df.drop_duplicates(keep = 'first', subset=['player_class','type','name','set','text'])
    print(df)

# %%
df = outer_join_df
unique_set(df)
# Out:
#         player_class         type               name      set  \
# card_id
# AT_001          MAGE        SPELL        Flame Lance      TGT
# AT_002          MAGE        SPELL             Effigy      TGT
# AT_003          MAGE       MINION        Fallen Hero      TGT
# AT_004          MAGE        SPELL       Arcane Blast      TGT
# AT_005          MAGE        SPELL    Polymorph: Boar      TGT
# ...              ...          ...                ...      ...
# skele21      NEUTRAL       MINION      Damaged Golem  EXPERT1
# tt_004       NEUTRAL       MINION  Flesheating Ghoul  EXPERT1
# tt_004o      NEUTRAL  ENCHANTMENT        Cannibalize  EXPERT1
# tt_010          MAGE        SPELL        Spellbender  EXPERT1
# tt_010a         MAGE       MINION        Spellbender  EXPERT1
#
#                                                       text  cost  attack  \
# card_id
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_002   <b>Secret:</b> When a friendly minion dies, su...   3.0     NaN
# AT_003               Your Hero Power deals 1 extra damage.   2.0     3.0
# AT_004   Deal $2 damage to a minion. This spell gets do...   1.0     NaN
# AT_005   Transform a minion into a 4/2 Boar with <b>Cha...   3.0     NaN
# ...                                                    ...   ...     ...
# skele21                                                NaN   1.0     2.0
# tt_004             Whenever a minion dies, gain +1 Attack.   3.0     2.0
# tt_004o                                  Increased Attack.   NaN     NaN
# tt_010   <b>Secret:</b> When an enemy casts a spell on ...   3.0     NaN
# tt_010a                                                NaN   1.0     1.0
#
#          health  rarity  collectible  \
# card_id
# AT_001      NaN  COMMON          1.0
# AT_002      NaN    RARE          1.0
# AT_003      2.0    RARE          1.0
# AT_004      NaN    EPIC          1.0
# AT_005      NaN    RARE          1.0
# ...         ...     ...          ...
# skele21     1.0  COMMON          NaN
# tt_004      3.0  COMMON          1.0
# tt_004o     NaN     NaN          NaN
# tt_010      NaN    EPIC          1.0
# tt_010a     3.0    EPIC          NaN
#
#                                                     flavor        race  \
# card_id
# AT_001   It's on the rack next to ice lance, acid lance...         NaN
# AT_002                                  Burning man, brah.         NaN
# AT_003                                And he can't get up.         NaN
# AT_004                           Now with 100% more blast!         NaN
# AT_005                                 It's always Huffer.         NaN
# ...                                                    ...         ...
# skele21                                                NaN  MECHANICAL
# tt_004   'Flesheating' is an unfair name.  It's just th...         NaN
# tt_004o                                                NaN         NaN
# tt_010   While it's fun to intercept enemy lightning bo...         NaN
# tt_010a                                                NaN         NaN
#
#         how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# AT_001          NaN                NaN                  NaN     NaN
# AT_002          NaN                NaN                  NaN     NaN
# AT_003          NaN                NaN                  NaN     NaN
# AT_004          NaN                NaN                  NaN     NaN
# AT_005          NaN                NaN                  NaN     NaN
# ...             ...                ...                  ...     ...
# skele21         NaN                NaN                  NaN     NaN
# tt_004          NaN                NaN                  NaN     NaN
# tt_004o         NaN                NaN                  NaN     NaN
# tt_010          NaN                NaN                  NaN     NaN
# tt_010a         NaN                NaN                  NaN     NaN
#
#          durability           action  cost_dust
# card_id
# AT_001          NaN  CRAFTING_NORMAL       40.0
# AT_002          NaN  CRAFTING_NORMAL      100.0
# AT_003          NaN  CRAFTING_NORMAL      100.0
# AT_004          NaN  CRAFTING_NORMAL      400.0
# AT_005          NaN  CRAFTING_NORMAL      100.0
# ...             ...              ...        ...
# skele21         NaN  CRAFTING_NORMAL       40.0
# tt_004          NaN  CRAFTING_NORMAL       40.0
# tt_004o         NaN              NaN        NaN
# tt_010          NaN  CRAFTING_NORMAL      400.0
# tt_010a         NaN  CRAFTING_NORMAL      400.0
#
# [2604 rows x 19 columns]

# %%
[df[i].unique().tolist() for i in df.columns]
# Out:
# [['MAGE',
#   'NEUTRAL',
#   'HUNTER',
#   'PRIEST',
#   'WARLOCK',
#   'ROGUE',
#   'DRUID',
#   'SHAMAN',
#   'WARRIOR',
#   'PALADIN',
#   'DREAM',
#   nan,
#   'DEATHKNIGHT'],
#  ['SPELL', 'MINION', 'ENCHANTMENT', 'WEAPON', 'HERO_POWER', 'HERO', nan],
#  ['Flame Lance',
#   'Effigy',
#   'Fallen Hero',
#   'Arcane Blast',
#   'Polymorph: Boar',
#   'Boar',
#   'Dalaran Aspirant',
#   'Power of Dalaran',
#   'Spellslinger',
#   'Coldarra Drake',
#   'Rhonin',
#   'Ram Wrangler',
#   'Holy Champion',
#   "Light's Blessing",
#   'Spawn of Shadows',
#   'Power Word: Glory',
#   'Shadowfiend',
#   'Shadowfiended',
#   'Convert',
#   'Confuse',
#   'Confused',
#   'Twilight Guardian',
#   "Twilight's Embrace",
#   'Confessor Paletress',
#   'Dreadsteed',
#   'Fearsome Doomguard',
#   'Tiny Knight of Evil',
#   'Felrage',
#   'Fist of Jaraxxus',
#   'Void Crusher',
#   'Demonfuse',
#   'Dark Fusion',
#   'Dark Bargain',
#   'Wrathguard',
#   'Wilfred Fizzlebang',
#   'Master Summoner',
#   'Shado-Pan Rider',
#   'Chi Lance',
#   'Buccaneer',
#   'Extra Stabby',
#   'Undercity Valiant',
#   'Cutpurse',
#   'Shady Dealer',
#   'Shady Deals',
#   'Burgle',
#   'Poisoned Blade',
#   'Laced',
#   'Beneath the Grounds',
#   'Ambush!',
#   "Anub'arak",
#   'Nerubian',
#   'Living Roots',
#   'Sapling',
#   'Darnassus Aspirant',
#   'Savage Combatant',
#   'Savage',
#   'Wildwalker',
#   'Kindred Spirit',
#   'Knight of the Wild',
#   'Call of the Wild',
#   'Druid of the Saber',
#   'Lion Form',
#   'Panther Form',
#   'Sabertooth Lion',
#   'Sabertooth Panther',
#   'Astral Communion',
#   'Mulch',
#   'Aviana',
#   'Empowering Mist',
#   'Mistcaller Deck Ench',
#   'Tuskarr Totemic',
#   'Draenei Totemcarver',
#   'Experienced',
#   'Healing Wave',
#   'Thunder Bluff Valiant',
#   'Power of the Bluff',
#   'Charged Hammer',
#   'Lightning Jolt',
#   'Elemental Destruction',
#   'Totem Golem',
#   'Ancestral Knowledge',
#   'The Mistcaller',
#   'Flash Heal',
#   'Powershot',
#   'Stablemaster',
#   'Groomed',
#   "King's Elekk",
#   'Brave Archer',
#   'Bear Trap',
#   'Lock and Load',
#   'Ball of Spiders',
#   'Acidmaw',
#   'Dreadscale',
#   'Bash',
#   "King's Defender",
#   'Orgrimmar Aspirant',
#   'Forges of Orgrimmar',
#   'Magnataur Alpha',
#   'Bolster',
#   'Bolstered',
#   'Sparring Partner',
#   'Training Complete',
#   "Skycap'n Kragg",
#   "Alexstrasza's Champion",
#   "Alexstrasza's Boon",
#   'Varian Wrynn',
#   'Competitive Spirit',
#   'Seal of Champions',
#   'Warhorse Trainer',
#   'Might of the Hostler',
#   'Murloc Knight',
#   'Argent Lance',
#   'Extra Poke',
#   'Enter the Coliseum',
#   'Mysterious Challenger',
#   'Garrison Commander',
#   'Eadric the Pure',
#   'Purified',
#   'Lowly Squire',
#   'Training',
#   'Dragonhawk Rider',
#   'Dragonhawkery',
#   'Lance Carrier',
#   'Equipped',
#   'Maiden of the Lake',
#   'Saboteur',
#   'Villainy',
#   'Argent Horserider',
#   "Mogor's Champion",
#   'Boneguard Lieutenant',
#   'Boneguarded',
#   "Mukla's Champion",
#   'Might of the Monkey',
#   'Tournament Medic',
#   'Ice Rager',
#   'Frigid Snobold',
#   'Flame Juggler',
#   'Silent Knight',
#   'Clockwork Knight',
#   'Wound Up',
#   'Tournament Attendee',
#   'Sideshow Spelleater',
#   'Kodorider',
#   'War Kodo',
#   'Silver Hand Regent',
#   'Pit Fighter',
#   'Captured Jormungar',
#   'North Sea Kraken',
#   'Tuskarr Jouster',
#   'Injured Kvaldir',
#   "Light's Champion",
#   'Armored Warhorse',
#   'Argent Watchman',
#   'Inspired',
#   'Coliseum Manager',
#   'Refreshment Vendor',
#   'Master Jouster',
#   'Recruiter',
#   'Evil Heckler',
#   'Fencing Coach',
#   'Fencing Practice',
#   'Wyrmrest Agent',
#   'Bring it on!',
#   'Master of Ceremonies',
#   'Ceremony',
#   'Grand Crusader',
#   'Kvaldir Raider',
#   'Frost Giant',
#   'Crowd Favorite',
#   'Huge Ego',
#   'Gormok the Impaler',
#   'Chillmaw',
#   'Bolf Ramshield',
#   'Icehowl',
#   'Nexus-Champion Saraad',
#   'The Skeleton Knight',
#   'Fjola Lightbane',
#   'Sea Reaver',
#   'Eydis Darkbane',
#   'Justicar Trueheart',
#   'Dire Shapeshift',
#   'Dire Claws',
#   'Ballista Shot',
#   'Fireblast Rank 2',
#   'The Silver Hand',
#   'Heal',
#   'Poisoned Daggers',
#   'Poisoned Dagger',
#   'Totemic Slam',
#   'Healing Totem',
#   'Searing Totem',
#   'Stoneclaw Totem',
#   'Wrath of Air Totem',
#   'Soul Tap',
#   'Tank Up!',
#   'Gadgetzan Jouster',
#   'Victory!',
#   'Coren Direbrew',
#   'Pile On!',
#   'Pile On!!!',
#   'Dark Iron Bouncer',
#   "Get 'em!",
#   'Guzzler',
#   'High Justice Grimstone',
#   'Jeering Crowd',
#   'Dark Iron Spectator',
#   'Emperor Thaurissan',
#   'Power of the Firelord',
#   'Moira Bronzebeard',
#   'Garr',
#   'Magma Pulse',
#   'Firesworn',
#   'Rock Out',
#   'Baron Geddon',
#   'Ignite Mana',
#   'Living Bomb',
#   'Majordomo Executus',
#   'The Majordomo',
#   'Ragnaros the Firelord',
#   'Flamewaker Acolyte',
#   'Highlord Omokk',
#   'ME SMASH',
#   'TIME FOR SMASH',
#   'General Drakkisath',
#   'Intense Gaze',
#   "Drakkisath's Command",
#   'Rend Blackhand',
#   'Open the Gates',
#   'Whelp',
#   'Old Horde',
#   'Old Horde Orc',
#   'Blackwing',
#   'Dragonkin',
#   'Dismount',
#   'Gyth',
#   'The True Warchief',
#   'Razorgore the Untamed',
#   'The Rookery',
#   'Incubation',
#   'Corrupted Egg',
#   'Chromatic Drake',
#   "Razorgore's Claws",
#   'Blind With Rage',
#   'Vaelastrasz the Corrupt',
#   'Essence of the Red',
#   'Burning Adrenaline',
#   'Chromaggus',
#   'Mutation',
#   'Brood Affliction',
#   'Brood Affliction: Red',
#   'Brood Affliction: Green',
#   'Brood Affliction: Blue',
#   'Brood Affliction: Black',
#   'Brood Affliction: Bronze',
#   'Chromatic Mutation',
#   'Chromatic Dragonkin',
#   'Draconic Lineage',
#   'Lord Victor Nefarius',
#   'True Form',
#   'Nefarian',
#   'Wild Magic',
#   'Son of the Flame',
#   'Living Lava',
#   'Whirling Ash',
#   'DIE, INSECT!',
#   'Omnotron Defense System',
#   'Activate!',
#   'Recharge',
#   'Magmaw',
#   'Activate Arcanotron',
#   'Arcanotron',
#   'Activate Toxitron',
#   'Toxitron',
#   'Activate Electron',
#   'Electron',
#   'Activate Magmatron',
#   'Magmatron',
#   'Maloriak',
#   'The Alchemist',
#   'Potion of Might',
#   'Release the Aberrations!',
#   'Aberration',
#   'Atramedes',
#   'Echolocate',
#   'Sonic Breath',
#   'Reverberating Gong',
#   'Dragonteeth',
#   'I hear you...',
#   'Onyxia',
#   'LAVA!',
#   'Bone Minions',
#   'Bone Construct',
#   'Chromatic Prototype',
#   'Nefarian Strikes!',
#   'Onyxiclaw',
#   'Flameheart',
#   'Dragonkin Spellcaster',
#   'Lucifron',
#   'I Hear You...',
#   'Drakonid Slayer',
#   'Sulfuras',
#   'Golemagg',
#   'Core Hound Puppies',
#   'Core Hound Pup',
#   'Vaelastrasz',
#   'Razorgore',
#   'Dragonlust',
#   'Rock Elemental',
#   'Solemn Vigil',
#   'Melt',
#   'Flamewaker',
#   "Dragon's Breath",
#   "Dragon's Might",
#   'Twilight Whelp',
#   'Twilight Endurance',
#   'Demonwrath',
#   'Imp Gang Boss',
#   'Imp',
#   'Gang Up',
#   'Dark Iron Skulker',
#   'Volcanic Lumberer',
#   'Druid of the Flame',
#   'Firecat Form',
#   'Fire Hawk Form',
#   'Lava Shock',
#   'Fireguard Destroyer',
#   'On Fire!',
#   'Quick Shot',
#   'Core Rager',
#   'Power Rager',
#   'Revenge',
#   'Axe Flinger',
#   'Resurrect',
#   'Dragon Consort',
#   'Unchained!',
#   'Grim Patron',
#   'Dragonkin Sorcerer',
#   'Draconic Power',
#   'Dragon Egg',
#   'Black Whelp',
#   'Drakonid Crusher',
#   'Large Talons',
#   'Volcanic Drake',
#   'Hungry Dragon',
#   'DIE, INSECTS!',
#   'Imperial Favor',
#   'Tail Swipe',
#   'Blackwing Technician',
#   'Dragon Blood',
#   'Blackwing Corruptor',
#   'Raza the Chained',
#   'Raza Enchant',
#   'Freezing Potion',
#   'Wind-up Burglebot',
#   'Hidden Cache',
#   'Smuggling',
#   'Street Trickster',
#   'Red Mana Wyrm',
#   'Mana Heist',
#   'Jinyu Waterspeaker',
#   'Grimestreet Protector',
#   'Kooky Chemist',
#   'Kooky Chemistry',
#   'Blubber Baron',
#   'Size Increase',
#   'Volcanic Potion',
#   'Kabal Lackey',
#   'Hozen Healer',
#   'Felfire Potion',
#   'Weasel Tunneler',
#   'Mistress of Mixtures',
#   'Public Defender',
#   "Smuggler's Run",
#   'Kun the Forgotten King',
#   'Forgotten Armor',
#   'Forgotten Mana',
#   'Call in the Finishers',
#   'Murloc Razorgill',
#   'Jade Chieftain',
#   'Finders Keepers',
#   'Alleycat',
#   'Tabbycat',
#   'Rat Pack',
#   'Rat',
#   'Grimestreet Informant',
#   'White Eyes',
#   'The Storm Guardian',
#   'Small-Time Buccaneer',
#   'Fight Promoter',
#   'Knuckles',
#   "Smuggler's Crate",
#   'Dispatch Kodo',
#   'Shaky Zipgunner',
#   'Piranha Launcher',
#   'Piranha',
#   'Trogg Beastrager',
#   'Sergeant Sally',
#   'Luckydo Buccaneer',
#   'Looted Blade',
#   'Jade Behemoth',
#   'Finja, the Flying Star',
#   'Jade Idol',
#   'Potion of Madness',
#   'Madness Potion',
#   'Greater Healing Potion',
#   'Drakonid Operative',
#   'Mana Geode',
#   'Crystal',
#   'Blastcrystal Potion',
#   'Fel Orc Soulfiend',
#   'Crystalweaver',
#   'Serrated Shadows',
#   'Bloodfury Potion',
#   'Demonic Draught',
#   'Mark of the Lotus',
#   'Savage Mark',
#   'Pilfered Power',
#   'Celestial Dreamer',
#   'Visions of Hypnos',
#   'Kabal Chemist',
#   'Potion of Polymorph',
#   'Kazakus',
#   'Kabal Demon',
#   'Sheep',
#   'Goldthorn',
#   'Kazakus Potion',
#   'Netherbloom',
#   'Lesser Potion',
#   'Greater Potion',
#   'Superior Potion',
#   'Heart of Fire',
#   'Stonescale Oil',
#   'Felbloom',
#   'Icecap',
#   'Mystic Wool',
#   'Kingsblood',
#   'Shadow Oil',
#   'Ichor of Undeath',
#   'Greater Arcane Missiles',
#   'Kabal Talonpriest',
#   'Fortitude',
#   'Counterfeit Coin',
#   'Brass Knuckles',
#   'Lotus Assassin',
#   'Shadow Rager',
#   'Patches the Pirate',
#   'Grimestreet Enforcer',
#   'Hobart Grapplehammer',
#   'Backstreet Leper',
#   'Blowgill Sniper',
#   'Big-Time Racketeer',
#   '"Little Friend"',
#   'Kabal Courier',
#   'Grimscale Chum',
#   'Naga Corsair',
#   'Extra Sharp',
#   'Second-Rate Bruiser',
#   'Hired Gun',
#   'Friendly Bartender',
#   'Toxic Sewer Ooze',
#   'Streetwise Investigator',
#   'Kabal Songstealer',
#   'Backroom Bouncer',
#   'Cut Off',
#   'Gadgetzan Socialite',
#   'Manic Soulcaster',
#   'Pint-Size Potion',
#   'Shrunk',
#   'Dragonfire Potion',
#   'Kabal Trafficker',
#   'Worgen Greaser',
#   'Grook Fu Master',
#   'Bomb Squad',
#   'Doppelgangster',
#   'Burgly Bully',
#   'Mayor Noggenfogger',
#   'Cryomancer',
#   'We All Scream',
#   'Madam Goya',
#   "Don Han'Cho",
#   'Inkmaster Solia',
#   'Free Spell',
#   'Spiked Hogrider',
#   'Jade Shuriken',
#   'Jade Swarmer',
#   'Gadgetzan Ferryman',
#   'Shadow Sensei',
#   'Trained',
#   'Devolve',
#   'Lotus Illusionist',
#   'Seadevil Stinger',
#   'Seadevil Enchant',
#   'Jade Lightning',
#   'Jade Golem',
#   'Jade Blossom',
#   'Jade Spirit',
#   'Sleep with the Fishes',
#   'Jade Claws',
#   'Krul the Unshackled',
#   'Abyssal Enforcer',
#   'Stolen Goods',
#   'Grimestreet Outfitter',
#   'Grimy Gadgeteer',
#   'Grimestreet Pawnbroker',
#   'Alley Armorsmith',
#   'Meanstreet Marshal',
#   'Kabal Crystal Runner',
#   'Shaku, the Collector',
#   'Dirty Rat',
#   'Getaway Kodo',
#   'Wrathion',
#   'Auctionmaster Beardo',
#   'Genzo, the Shark',
#   'Tanaris Hogchopper',
#   'Leatherclad Hogleader',
#   'Lunar Visions',
#   'Wickerflame Burnbristle',
#   'Virmen Sensei',
#   'Get Big',
#   'Daring Reporter',
#   'The Scoop',
#   'Lotus Agents',
#   'Grimestreet Smuggler',
#   'Ancient of Blossoms',
#   'Defias Cleaner',
#   'Unlicensed Apothecary',
#   'Aya Blackpaw',
#   'Small-Time Recruits',
#   'I Know a Guy',
#   'Jason Chayes',
#   'Eric Dodds',
#   'Bob Fitch',
#   'Steven Gabriel',
#   'Kyle Harrison',
#   'Derek Sakamoto',
#   'Zwick',
#   'Ben Brode',
#   'Ben Thompson',
#   'Michael Schweitzer',
#   'Jay Baxter',
#   'Rachelle Davis',
#   'Brian Schwab',
#   'Yong Woo',
#   'Andy Brock',
#   'Hamilton Chu',
#   'Rob Pardo',
#   'Becca Abel',
#   'Beomki Hong',
#   'Brian Birmingham',
#   'Bryan Chang',
#   'Cameron Chrisman',
#   'Christopher Yim',
#   'Dean Ayala',
#   'Elizabeth Cho',
#   'Eric Del Priore',
#   'Henry Ho',
#   'He-Rim Woo',
#   'Jason MacAllister',
#   'JC Park',
#   'Jeremy Cranford',
#   'Jerry Mascho',
#   'Jomaro Kindred',
#   'Max Ma',
#   'Max McCall',
#   'Mike Donais',
#   'Ricardo Robaina',
#   'Robin Fredericksen',
#   'Ryan Chew',
#   'Ryan Masterson',
#   'Seyil Yoon',
#   'Tim Erskine',
#   'Jon Bankard',
#   'Walter Kong',
#   'Jonas Laster',
#   'Keith Landes',
#   'Goldshire Footman',
#   'Fen Creeper',
#   'Holy Nova',
#   'Mind Control',
#   'Inner Fire',
#   'Holy Smite',
#   'Lesser Heal',
#   'Mind Vision',
#   'Power Word: Shield',
#   'Claw',
#   'Healing Touch',
#   'Moonfire',
#   'Mark of the Wild',
#   'Savage Roar',
#   'Swipe',
#   'Wild Growth',
#   'Excess Mana',
#   'Shapeshift',
#   'Claws',
#   'Polymorph',
#   'Arcane Intellect',
#   'Frostbolt',
#   'Arcane Explosion',
#   'Frost Nova',
#   'Mirror Image',
#   'Blizzard',
#   'Fireball',
#   'Ice Lance',
#   'Flamestrike',
#   'Water Elemental',
#   'Fireblast',
#   'Frost Shock',
#   'Ancestral Spirit',
#   'Windfury',
#   'Ancestral Healing',
#   'Ancestral Infusion',
#   'Fire Elemental',
#   'Rockbiter Weapon',
#   'Bloodlust',
#   'Totemic Call',
#   'Far Sight',
#   'Life Tap',
#   'Shadow Bolt',
#   'Blood Imp',
#   'Blood Pact',
#   'Drain Life',
#   'Hellfire',
#   'Corruption',
#   'Dread Infernal',
#   'Voidwalker',
#   'Backstab',
#   'Cold Blood',
#   'Deadly Poison',
#   'Sinister Strike',
#   'Assassinate',
#   'Sprint',
#   "Assassin's Blade",
#   'Wicked Knife',
#   'Dagger Mastery',
#   'Sharpened',
#   "Hunter's Mark",
#   'Blessing of Might',
#   'Guardian of Kings',
#   'Holy Light',
#   "Light's Justice",
#   'Blessing of Kings',
#   'Consecration',
#   'Hammer of Wrath',
#   'Truesilver Champion',
#   'Reinforce',
#   'Silver Hand Recruit',
#   'Armor Up!',
#   'Charge',
#   'Rampage',
#   'Heroic Strike',
#   'Fiery War Axe',
#   'Execute',
#   'Arcanite Reaper',
#   'Cleave',
#   'Earthen Ring Farseer',
#   'Magma Rager',
#   'Oasis Snapjaw',
#   'River Crocolisk',
#   'Frostwolf Grunt',
#   'Raid Leader',
#   'Enhanced',
#   'Wolfrider',
#   'Ironfur Grizzly',
#   'Silverback Patriarch',
#   'Stormwind Knight',
#   'Ironforge Rifleman',
#   'Kobold Geomancer',
#   'Southsea Deckhand',
#   'Gnomish Inventor',
#   'Stormpike Commando',
#   'Silver Hand Knight',
#   'Squire',
#   'Archmage',
#   'Ravenholdt Assassin',
#   'Lord of the Arena',
#   'Murloc Raider',
#   'Young Dragonhawk',
#   'Stonetusk Boar',
#   'Bloodfen Raptor',
#   'Bluegill Warrior',
#   "Sen'jin Shieldmasta",
#   'Injured Blademaster',
#   'Full Strength',
#   'Chillwind Yeti',
#   'War Golem',
#   'Booty Bay Bodyguard',
#   'Abusive Sergeant',
#   "'Inspired'",
#   'Elven Archer',
#   'Razorfen Hunter',
#   'Ogre Magi',
#   'Boulderfist Ogre',
#   'Core Hound',
#   'Ironbeak Owl',
#   'Reckless Rocketeer',
#   'Spiteful Smith',
#   'Sharp!',
#   'Stormwind Champion',
#   'Might of Stormwind',
#   'Frostwolf Warlord',
#   'Frostwolf Banner',
#   'Venture Co. Mercenary',
#   'Wisp',
#   'Ironbark Protector',
#   'Blade Flurry',
#   'Shadow Word: Pain',
#   'Northshire Cleric',
#   'Divine Spirit',
#   'Starving Buzzard',
#   'Laughing Sister',
#   'Ysera Awakens',
#   'Emerald Drake',
#   'Dream',
#   'Nightmare',
#   'Darkscale Healer',
#   'Houndmaster',
#   "Master's Presence",
#   'Timber Wolf',
#   'Furious Howl',
#   'Tundra Rhino',
#   'Multi-Shot',
#   'Tracking',
#   'Arcane Shot',
#   "Gladiator's Longbow",
#   "Gladiator's Longbow enchantment",
#   'Mind Blast',
#   'Steady Shot',
#   'Lightwarden',
#   'Warded',
#   'The Black Knight',
#   'Young Priestess',
#   "Elune's Grace",
#   'Big Game Hunter',
#   'Alarm-o-Bot',
#   'Acolyte of Pain',
#   'Argent Squire',
#   'Angry Chicken',
#   'Enraged',
#   'Worgen Infiltrator',
#   'Voodoo Doctor',
#   'Bloodmage Thalnos',
#   'King Mukla',
#   'Bananas',
#   'Novice Engineer',
#   'Sylvanas Windrunner',
#   'Jungle Panther',
#   'Shattered Sun Cleric',
#   "Cleric's Blessing",
#   'Scarlet Crusader',
#   'Thrallmar Farseer',
#   'Silvermoon Guardian',
#   'Dragonling Mechanic',
#   'Mechanical Dragonling',
#   'Stranglethorn Tiger',
#   'Leper Gnome',
#   'Sunwalker',
#   'Windfury Harpy',
#   'Twilight Drake',
#   'Hour of Twilight',
#   'Questing Adventurer',
#   'Level Up!',
#   'Ancient Watcher',
#   'Dark Iron Dwarf',
#   'Tempered',
#   'Spellbreaker',
#   'Youthful Brewmaster',
#   'Coldlight Oracle',
#   'Mana Addict',
#   'Empowered',
#   'Ancient Brewmaster',
#   'Sunfury Protector',
#   'Crazed Alchemist',
#   'Experiments!',
#   'Old Murk-Eye',
#   'Acidic Swamp Ooze',
#   'Argent Commander',
#   'Pint-Sized Summoner',
#   'Secretkeeper',
#   'Keeping Secrets',
#   'Mad Bomber',
#   'Tinkmaster Overspark',
#   'Warsong Commander',
#   'Mind Control Tech',
#   'Arcane Golem',
#   'Cabal Shadow Priest',
#   'Defender of Argus',
#   'Hand of Argus',
#   'Gadgetzan Auctioneer',
#   'Loot Hoarder',
#   'Abomination',
#   'Lorewalker Cho',
#   'Demolisher',
#   'Coldlight Seer',
#   'Mrghlglhal',
#   'Mountain Giant',
#   'Cairne Bloodhoof',
#   'Baine Bloodhoof',
#   'Gelbin Mekkatorque',
#   'Leeroy Jenkins',
#   'Eviscerate',
#   'Betrayal',
#   'Conceal',
#   'Concealed',
#   'Fan of Knives',
#   'Noble Sacrifice',
#   'Defender',
#   'Defias Ringleader',
#   'Defias Bandit',
#   'Eye for an Eye',
#   "Perdition's Blade",
#   'SI:7 Agent',
#   'Redemption',
#   'Headcrack',
#   'Shadowstep',
#   'Preparation',
#   'Wrath',
#   'Mark of Nature',
#   'Soul of the Forest',
#   'Treant',
#   'Power of the Wild',
#   'Summon a Panther',
#   'Leader of the Pack',
#   'Panther',
#   'Naturalize',
#   'Dire Wolf Alpha',
#   'Strength of the Pack',
#   'Nourish',
#   'Druid of the Claw',
#   'Cat Form',
#   'Bear Form',
#   'Keeper of the Grove',
#   'Dispel',
#   'Innervate',
#   'Emperor Cobra',
#   'Starfire',
#   'Ancient of War',
#   'Rooted',
#   'Uproot',
#   'Uprooted',
#   'Lightning Bolt',
#   'Lava Burst',
#   'Dust Devil',
#   'Totemic Might',
#   'Earth Shock',
#   'Hex',
#   'Hexxed',
#   'Stormforged Axe',
#   'Feral Spirit',
#   'Earth Elemental',
#   'Forked Lightning',
#   'Unbound Elemental',
#   'Overloading',
#   'Lightning Storm',
#   'Ethereal Arcanist',
#   'Raw Power!',
#   'Cone of Cold',
#   'Arcane Missiles',
#   'Shiv',
#   'Pyroblast',
#   'Frost Elemental',
#   'Azure Drake',
#   'Counterspell',
#   'Ice Barrier',
#   'Mirror Entity',
#   'Ice Block',
#   'Felguard',
#   'Mortal Coil',
#   'Shadowflame',
#   'Void Terror',
#   'Consume',
#   'Succubus',
#   'Soulfire',
#   'Siphon Soul',
#   'Doomguard',
#   'Twisting Nether',
#   'Pit Lord',
#   'Summoning Portal',
#   'Power Overwhelming',
#   'Sense Demons',
#   'Worthless Imp',
#   'Flame Imp',
#   'Bane of Doom',
#   'Lord Jaraxxus',
#   'Blood Fury',
#   'Silence',
#   'Shadow Madness',
#   'Lightspawn',
#   'Thoughtsteal',
#   'Lightwell',
#   'Mindgames',
#   'Shadow of Nothing',
#   'Divine Favor',
#   'Prophet Velen',
#   'Lay on Hands',
#   'Blessed Champion',
#   'Humility',
#   'Argent Protector',
#   'Blessing of Wisdom',
#   'Holy Wrath',
#   'Sword of Justice',
#   'Justice Served',
#   'Hand of Protection',
#   'Repentance',
#   'Aldor Peacekeeper',
#   'Stand Down!',
#   'Tirion Fordring',
#   'Ashbringer',
#   'Avenging Wrath',
#   'Tauren Warrior',
#   'Slam',
#   'Battle Rage',
#   'Amani Berserker',
#   "Mogu'shan Warden",
#   'Arathi Weaponsmith',
#   'Battle Axe',
#   'Gurubashi Berserker',
#   'Berserking',
#   'Whirlwind',
#   'Armorsmith',
#   'Shieldbearer',
#   'Brawl',
#   'Mortal Strike',
#   'Upgrade!',
#   'Upgraded',
#   'Heavy Axe',
#   'Shield Slam',
#   'Gorehowl',
#   'Bloodrage',
#   'Needs Sharpening',
#   'Raging Worgen',
#   'Grommash Hellscream',
#   'Murloc Tidehunter',
#   'Murloc Scout',
#   'Murloc Warleader',
#   'Mrgglaargl!',
#   'Grimscale Oracle',
#   'Mlarggragllabl!',
#   'Murloc Tidecaller',
#   'Blarghghl',
#   'Patient Assassin',
#   'Scavenging Hyena',
#   'Well Fed',
#   'Misdirection',
#   'Savannah Highmane',
#   'Hyena',
#   'Eaglehorn Bow',
#   'Explosive Shot',
#   'Unleash the Hounds',
#   'Hound',
#   'Kill Command',
#   'King Krush',
#   'Flare',
#   'Bestial Wrath',
#   'Snake Trap',
#   'Snake',
#   'Harvest Golem',
#   'Nat Pagle',
#   'Harrison Jones',
#   'Archmage Antonidas',
#   'Nozdormu',
#   'Alexstrasza',
#   "Alexstrasza's Fire",
#   'Malygos',
#   'Faceless Manipulator',
#   'Flametongue Totem',
#   'Flametongue',
#   'Doomhammer',
#   'Bite',
#   'Force of Nature',
#   'Ysera',
#   'Cenarius',
#   "Demigod's Favor",
#   "Shan'do's Lesson",
#   'Mana Tide Totem',
#   'The Beast',
#   'Savagery',
#   'Sap',
#   'Dalaran Mage',
#   'Priestess of Elune',
#   'Ancient Mage',
#   'Teachings of the Kirin Tor',
#   'Sea Giant',
#   'Windspeaker',
#   'Blood Knight',
#   "Shadows of M'uru",
#   'Auchenai Soulpriest',
#   'Nightblade',
#   'Vaporize',
#   'Cult Master',
#   'Demonfire',
#   'Imp Master',
#   'Cruel Taskmaster',
#   'Whipped Into Shape',
#   'Frothing Berserker',
#   'Berserk',
#   'Shield Block',
#   'Inner Rage',
#   "Sorcerer's Apprentice",
#   'Snipe',
#   'Explosive Trap',
#   ...],
#  ['TGT',
#   'BRM',
#   'TB',
#   'GANGS',
#   'CREDITS',
#   'CORE',
#   'EXPERT1',
#   'HERO_SKINS',
#   'REWARD',
#   'PROMO',
#   'NAXX',
#   'GVG',
#   'KARA',
#   'LOE',
#   'OG',
#   nan,
#   'MISSIONS',
#   'CHEAT'],
#  ['Deal $8 damage to a minion.',
#   '<b>Secret:</b> When a friendly minion dies, summon a random minion with the same Cost.',
#   'Your Hero Power deals 1 extra damage.',
#   'Deal $2 damage to a minion. This spell gets double bonus from <b>Spell Damage</b>.',
#   'Transform a minion into a 4/2 Boar with <b>Charge</b>.',
#   '<b>Charge</b>',
#   '<b>Inspire:</b> Gain <b>Spell Damage +1</b>.',
#   'Increased Spell Damage.',
#   "<b>Battlecry:</b> Add a random spell to each player's hand.",
#   'You can use your Hero Power any number of times.',
#   '<b>Deathrattle:</b> Add 3 copies of Arcane Missiles to your hand.',
#   '<b>Battlecry:</b> If you have a Beast, summon a\nrandom Beast.',
#   'Whenever a character is healed, gain +2 Attack.',
#   'Increased Attack.',
#   '<b>Inspire:</b> Deal 4 damage to each hero.',
#   'Choose a minion. Whenever it attacks, restore 4 Health to\nyour hero.',
#   'When this attacks, restore 4 Health to the hero of the player who buffed it.',
#   'Whenever you draw a card, reduce its Cost by (1).',
#   'Costs (1) less.',
#   'Put a copy of an enemy minion into your hand.',
#   'Swap the Attack and Health of all minions.',
#   'Swapped Attack and Health.',
#   "<b>Battlecry:</b> If you're holding a Dragon, gain +1 Attack and <b>Taunt</b>.",
#   '+1 Attack and <b>Taunt</b>.',
#   '<b>Inspire:</b> Summon a random <b>Legendary</b> minion.',
#   '<b>Deathrattle:</b> Summon a Dreadsteed.',
#   nan,
#   'Whenever you discard a card, gain +1/+1.',
#   'Increased stats.',
#   'When you play or discard this, deal $4 damage to a random enemy.',
#   '<b>Inspire:</b> Destroy a random minion for each player.',
#   'Give a Demon +3/+3. Give your opponent a Mana Crystal.',
#   '+3/+3.',
#   'Destroy 2 random enemy minions. Discard 2 random cards.',
#   'Whenever this minion takes damage, also deal that amount to your hero.',
#   'Cards you draw from your Hero Power cost (0).',
#   'Costs (0).',
#   '<b>Combo:</b> Gain +3 Attack.',
#   '+3 Attack.',
#   'Whenever you equip a weapon, give it +1 Attack.',
#   '+1 Attack',
#   '<b>Combo:</b> Deal 1 damage.',
#   'Whenever this minion attacks a hero, add the Coin to your hand.',
#   '<b>Battlecry:</b> If you have a Pirate, gain +1/+1.',
#   '+1/+1.',
#   "Add 2 random class cards to your hand <i>(from your opponent's class)</i>.",
#   'Your Hero Power gives this weapon +1 Attack instead of replacing it.',
#   "Shuffle 3 Ambushes into your opponent's deck. When drawn, you summon a 4/4 Nerubian.",
#   'When you draw this, summon a 4/4 Nerubian for your opponent. Draw a card.',
#   '<b>Deathrattle:</b> Return this to your hand and summon a 4/4 Nerubian.',
#   '<b>Choose One -</b> Deal $2 damage; or Summon two 1/1 Saplings.',
#   'Deal $2 damage.',
#   'Summon two 1/1 Saplings.',
#   '<b>Battlecry:</b> Gain an empty Mana Crystal.\n<b>Deathrattle:</b> Lose a Mana Crystal.',
#   '<b>Inspire:</b> Give your hero\n+2 Attack this turn.',
#   '+2 Attack this turn.',
#   '<b>Battlecry:</b> Give a friendly Beast +3 Health.',
#   '+3 Health.',
#   'Whenever you summon a Beast, reduce the Cost of this card by (1).',
#   'Cost reduced.',
#   '<b>Choose One -</b> Transform to gain <b>Charge</b>; or +1/+1 and <b>Stealth</b>.',
#   '+1/+1 and <b>Stealth</b>',
#   '<b>Stealth</b>',
#   'Gain 10 Mana Crystals. Discard your hand.',
#   "Destroy a minion.\nAdd a random minion to your opponent's hand.",
#   'Your minions cost (1).',
#   '<b>Battlecry:</b> Summon a random basic Totem.',
#   '<b>Battlecry:</b> Gain +1/+1 for each friendly Totem.',
#   'Restore #7 Health. Reveal a minion in each deck. If yours costs more, Restore #14 instead.',
#   '<b>Inspire:</b> Give your Totems +2 Attack.',
#   "<b>Deathrattle:</b> Your Hero Power becomes 'Deal 2 damage.'",
#   '<b>Hero Power</b>\nDeal $2 damage.',
#   'Deal $4-$5 damage to all minions. <b>Overload:</b> (5).',
#   '<b>Overload:</b> (1)',
#   'Draw 2 cards. <b>Overload:</b> (2)',
#   '<b>Battlecry:</b> Give all minions in your hand and deck +1/+1.',
#   'Restore #5 Health.',
#   'Deal $2 damage to a minion and the minions next to it.',
#   '<b>Battlecry:</b> Give a friendly Beast <b>Immune</b> this turn.',
#   '<b>Immune</b> this turn.',
#   '<b>Battlecry:</b> Reveal a minion in each deck. If yours costs more, draw it.',
#   '<b>Inspire:</b> If your hand is empty, deal 2 damage to the enemy hero.',
#   '<b>Secret:</b> After your hero is attacked, summon a 3/3 Bear with <b>Taunt</b>.',
#   'Each time you cast a spell this turn, add a random Hunter card to your hand.',
#   'Summon three 1/1 Webspinners.',
#   'Whenever another minion takes damage, destroy it.',
#   'At the end of your turn, deal 1 damage to all other minions.',
#   'Deal $3 damage.\nGain 3 Armor.',
#   '<b>Battlecry:</b> If you have a minion with <b>Taunt</b>,  gain +1 Durability.',
#   '+1 Durability.',
#   '<b>Inspire:</b> Give your weapon +1 Attack.',
#   'Also damages the minions next to whomever\nhe attacks.',
#   'Give your <b>Taunt</b> minions +2/+2.',
#   '+2/+2.',
#   '<b>Taunt</b>\n<b>Battlecry:</b> Give a\nminion <b>Taunt</b>.',
#   '<b>Taunt</b>',
#   '<b>Charrrrrge</b>\nCosts (1) less for each friendly Pirate.',
#   "<b>Battlecry:</b> If you're holding a Dragon, gain +1 Attack and <b>Charge</b>.",
#   '+1 Attack and <b>Charge</b>.',
#   '<b>Battlecry:</b> Draw 3 cards.\nPut any minions you drew directly into the battlefield.',
#   '<b>Secret:</b> When your turn starts, give your minions +1/+1.',
#   'Give a minion\n+3 Attack and <b>Divine Shield</b>.',
#   '+3 Attack and <b>Divine Shield</b>.',
#   'Your Silver Hand Recruits have +1 Attack.',
#   'Warhorse Trainer is granting this minion +1 Attack.',
#   '<b>Inspire:</b> Summon a random Murloc.',
#   '<b>Battlecry:</b> Reveal a minion in each deck. If yours costs more, +1 Durability.',
#   "Destroy all minions except each player's highest Attack minion.",
#   '<b>Battlecry:</b> Put one of each <b>Secret</b> from your deck into the battlefield.',
#   'You can use your Hero Power twice a turn.',
#   "<b>Battlecry:</b> Change all enemy minions'\nAttack to 1.",
#   'Attack changed to 1.',
#   '<b>Inspire:</b> Gain +1 Attack.',
#   '<b>Inspire:</b> Gain <b>Windfury</b>\nthis turn.',
#   '<b>Windfury</b> this turn.',
#   '<b>Battlecry:</b> Give a friendly minion +2 Attack.',
#   '+2 Attack.',
#   'Your Hero Power costs (1).',
#   "<b>Battlecry:</b> Your opponent's Hero Power costs (5) more next turn.",
#   'Your Hero Power costs (5) more this turn.',
#   '<b>Charge</b>\n<b>Divine Shield</b>',
#   '50% chance to attack the wrong enemy.',
#   '<b>Inspire:</b> Gain +1 Health.',
#   'Increased Health.',
#   '<b>Inspire:</b> Give your other minions +1/+1.',
#   '<b>Inspire:</b> Restore 2 Health to your hero.',
#   '<b>Spell Damage +1</b>',
#   '<b>Battlecry:</b> Deal 1 damage to a random enemy.',
#   '<b>Stealth</b>\n<b>Divine Shield</b>',
#   '<b>Battlecry:</b> Give a friendly Mech +1/+1.',
#   "<b>Battlecry:</b> Copy your opponent's Hero Power.",
#   '<b>Inspire:</b> Summon a 3/5 War Kodo.',
#   '<b>Inspire:</b> Summon a 1/1 Silver Hand Recruit.',
#   '<b>Battlecry:</b> Deal 4 damage.',
#   '<b>Battlecry:</b> Reveal a minion in each deck. If yours costs more, restore 7 Health to your hero.',
#   '<b>Battlecry:</b> Deal 3 damage to this minion.',
#   '<b>Battlecry:</b> <b>Silence</b> a Demon.',
#   '<b>Battlecry:</b> Reveal a minion in each deck. If yours costs more, gain <b>Charge</b>.',
#   "Can't attack.\n<b>Inspire:</b> Can attack as normal this turn.",
#   'Can attack this turn.',
#   '<b>Inspire:</b> Return this minion to your hand.',
#   '<b>Battlecry:</b> Restore 4 Health to each hero.',
#   '<b>Battlecry:</b> Reveal a minion in each deck. If yours costs more, gain <b>Taunt</b> and <b>Divine Shield</b>.',
#   '<b>Inspire:</b> Add a 2/2 Squire to your hand.',
#   '<b>Battlecry:</b> The next time you use your Hero Power, it costs (2) less.',
#   'Your Hero Power costs (2) less.',
#   '<b>Battlecry:</b> If you have a minion with <b>Spell Damage</b>, gain +2/+2.',
#   '<b>Battlecry:</b> Add a random Paladin card to your hand.',
#   '<b>Inspire:</b> Gain +2/+2.',
#   'Costs (1) less for each time you used your Hero Power this game.',
#   'Whenever you play a card with <b>Battlecry</b>, gain +1/+1.',
#   '<b>Battlecry:</b> If you have at least 4 other minions, deal 4 damage.',
#   "[x]<b>Taunt</b>\n<b>Deathrattle:</b> If you're holding\na Dragon, deal 3 damage\nto all minions.",
#   'Whenever your hero takes damage, this minion takes it instead.',
#   "<b>Charge</b>\nCan't attack heroes.",
#   '<b>Inspire:</b> Add a random spell to your hand.',
#   '<b>Deathrattle:</b> Reveal a minion in each deck. If yours costs more, return this to your hand.',
#   'Whenever <b>you</b> target this minion with a spell, gain <b>Divine Shield.</b>',
#   'When you draw this, deal 1 damage to your minions.',
#   'Whenever <b>you</b> target this minion with a spell, deal 3 damage to a random enemy.',
#   '<b>Battlecry:</b> Replace your starting Hero Power with a better one.',
#   '<b>Hero Power</b>\nGain 2 Armor and +2 Attack this turn.',
#   '<b>Hero Power</b>\nDeal $3 damage to the enemy hero.',
#   '<b>Hero Power</b>\nSummon two 1/1 Recruits.',
#   '<b>Hero Power</b>\nRestore #4 Health.',
#   '<b>Hero Power</b>\nEquip a 2/2 Weapon.',
#   '<b>Hero Power</b>\nSummon a Totem of your choice.',
#   'At the end of your turn, restore 1 Health to all friendly minions.',
#   '<b>Hero Power</b>\nDraw a card.',
#   '<b>Hero Power</b>\nGain 4 Armor.',
#   '<b>Battlecry:</b> Reveal a minion in each deck. If yours costs more, gain +1/+1.',
#   '<b>Hero Power</b>\nPut a minion from each deck into the battlefield.',
#   "<b>Hero Power</b>\nPut two minions from your deck and one from your opponent's into the battlefield.",
#   'Always wins Brawls.',
#   'Summon four 1/1 Dwarves with <b>Taunt</b>.',
#   '<b>Hero Power</b>\nSummon a 1/1 Spectator with <b>Taunt</b>.',
#   'Summon a 1/1 Spectator with <b>Taunt</b>.',
#   '<b>Hero Power</b>\nDeal 30 damage.',
#   "Thaurissan's Hero Power can't be used.\nNever attacks minions unless they have <b>Taunt</b>.",
#   '<b>Hero Power</b>\nDeal 1 damage to all minions.',
#   '<b>Deathrattle:</b> Deal 1 damage to the enemy hero for each Firesworn that died this turn.',
#   '<b>Deathrattle:</b> Deal 3 damage to the enemy hero for each Firesworn that died this turn.',
#   'Summon 3 Firesworn. <b>Overload:</b> (2)',
#   '<b>Hero Power</b>\nDeal 5 damage to the enemy hero if they have any unspent Mana.',
#   '<b>Hero Power</b>\nDeal 10 damage to the enemy hero if they have any unspent Mana.',
#   'Choose an enemy minion. If it lives until your next turn, deal $5 damage to all enemies.',
#   'Choose an enemy minion. If it lives until your next turn, deal $10 damage to all enemies.',
#   "On Geddon's turn, deal 10 damage to all of your stuff.",
#   "On Geddon's turn, deal 5 damage to all of your stuff.",
#   '<b>Hero Power</b>\nSummon a 1/3 Flamewaker Acolyte.',
#   '<b>Hero Power</b>\nSummon a 3/3 Flamewaker Acolyte.',
#   '<b>Hero Power</b>\nDestroy a random damaged enemy minion.',
#   '<b>Hero Power</b>\nDestroy a random enemy minion.',
#   'Destroy a random enemy minion.',
#   'Deal $5 damage to a random enemy. Gain 5 Armor.',
#   '<b>Passive Hero Power</b>\nAll cards cost (1). Players are capped at 1 Mana Crystal.',
#   '<b>Passive Hero Power</b>\nAll cards cost (1). You are capped at 2 Mana Crystals, and opponent at 1.',
#   'Destroy a minion. Gain 10 Armor.',
#   '<b>Hero Power</b>\nSummon three 1/1 Whelps. Get a new Hero Power.',
#   '<b>Hero Power</b>\nSummon three 2/2 Whelps. Get a new Hero Power.',
#   '<b>Hero Power</b>\nSummon three 1/1 Whelps.',
#   '<b>Hero Power</b>\nSummon two 1/1 Orcs with <b>Taunt</b>. Get a new Hero Power.',
#   '<b>Hero Power</b>\nSummon two 2/2 Orcs with <b>Taunt</b>. Get a new Hero Power.',
#   '<b>Hero Power</b>\nSummon a 3/1 Dragonkin. Get a new Hero Power.',
#   '<b>Hero Power</b>\nSummon a 5/4 Dragonkin. Get a new Hero Power.',
#   '<b>Hero Power</b>\nSummon Gyth. Get a new Hero Power.',
#   'Destroy a Legendary minion.',
#   '<b>Hero Power</b>\nGive all Corrupted Eggs +1 Health, then summon one.',
#   'When this minion has 4 or more Health, it hatches.',
#   'When this minion has 5 or more Health, it hatches.',
#   'Whenever a Corrupted Egg dies, gain +1 Attack.',
#   '<b>Hero Power</b>\nEach player draws 2 cards.',
#   '<b>Hero Power</b>\nEach player draws 3 cards. Gain a Mana Crystal.',
#   'Deal $2 damage to the enemy hero.',
#   '<b>Hero Power</b>\nDiscard a random card.',
#   "<b>Hero Power</b>\nAt the end of your turn, add a Brood Affliction card to your opponent's hand.",
#   'While this is in your hand, take 1 damage at the start of your turn.',
#   'While this is in your hand, take 3 damage at the start of your turn.',
#   'While this is in your hand, restore 2 health to your opponent at the start of your turn.',
#   'While this is in your hand, restore 6 health to your opponent at the start of your turn.',
#   "While this is in your hand, Chromaggus' spells cost (1) less.",
#   "While this is in your hand, Chromaggus' spells cost (3) less.",
#   'While this is in your hand, whenever Chromaggus draws a card, he gets another copy of it.',
#   "While this is in your hand, Chromaggus' minions cost (1) less.",
#   "While this is in your hand, Chromaggus' minions cost (3) less.",
#   'Transform a minion into a 2/2 Chromatic Dragonkin.',
#   'Whenever your opponent casts a spell, gain +2/+2.',
#   '+2/+2',
#   '<b>Hero Power</b>\nLet the games begin!',
#   "<b>Hero Power</b>\nPut a random spell from your opponent's class into your hand.",
#   '<b>Battlecry:</b> Deal 6 damage.',
#   '<b>Windfury</b>',
#   'Deal $8 damage to a random enemy.',
#   '<b>Hero Power</b>\nActivate a random Tron.',
#   'Fill all empty Mana Crystals.',
#   '<b>Hero Power</b>\nActivate Arcanotron!',
#   'Both players have <b>Spell Damage +2</b>.',
#   '<b>Hero Power</b>\nActivate Toxitron!',
#   'At the start of your turn, deal 1 damage to all other minions.',
#   '<b>Hero Power</b>\nActivate Electron!',
#   'All spells cost (3) less.',
#   '<b>Hero Power</b>\nActivate Magmatron!',
#   'Whenever a player plays a card, Magmatron deals 2 damage to them.',
#   '<b>Passive Hero Power</b>\nWhenever a minion is summoned, swap its Attack and Health.',
#   "<b>Passive Hero Power</b>\nMinions' Attack and Health are swapped.\nYour minions have +2/+2.",
#   'Summon 3 Aberrations.',
#   '<b>Hero Power</b>\nEquip a weapon that grows as your opponent plays cards.',
#   'Deal $3 damage to a minion. Give your weapon +3 Attack.',
#   "Destroy your opponent's weapon.",
#   'Whenever your opponent plays a card, gain +1 Attack.',
#   'Deal $2 damage to all minions.',
#   '<b>Hero Power</b>\nSummon two 2/1 Bone Constructs.',
#   '<b>Hero Power</b>\nSummon two 4/2 Bone Constructs.',
#   '<b>Hero Power</b>\nNefarian rains fire from above!',
#   'Draw 2 cards.\nGain 4 Armor.',
#   "On Ragnaros' turn, deal 5 damage to this side of the board.",
#   'Fill your board with 2/2 Whelps.',
#   '<b>Battlecry:</b> Summon two 2/2 Whelps.',
#   '<b>Battlecry:</b> Cast Corruption on all other minions.',
#   'Whenever your opponent plays a card, gain +2 Attack.',
#   '<b>Deathrattle:</b> Summon Emperor Thaurissan.',
#   'Also damages the minions next to whomever he attacks.',
#   'Always wins Brawls.\n <b>Battlecry:</b> Add a Brawl to your hand.',
#   'Summon a random Tron.',
#   "<b>Deathrattle:</b> Your Hero Power becomes 'Deal 8 damage to a random enemy'.",
#   'Costs (1) less for each damage your hero has taken.',
#   'Summon two 2/4 Core Hound Pups.',
#   'At the end of each turn, summon all Core Hound Pups that died this turn.',
#   'At the start of your turn, summon a <b>Legendary</b> minion.',
#   'Your cards cost (3) less.',
#   'Costs (2) less.',
#   'At the start of your turn, give your minions +3 Attack.',
#   'Whenever this minion takes damage, summon a 2/3 Elemental with <b>Taunt</b>.',
#   'Draw 2 cards. Costs (1) less for each minion that died this turn.',
#   'Attack changed to 0 this turn.',
#   'After you cast a spell, deal 2 damage randomly split among all enemies.',
#   'Deal $4 damage. Costs (1) less for each minion that died this turn.',
#   'Costs (3) less this turn.',
#   "<b>Battlecry:</b> If you're holding a Dragon, gain +2 Health.",
#   'Deal $2 damage to all non-Demon minions.',
#   'Whenever this minion takes damage, summon a 1/1 Imp.',
#   'Choose a minion. Shuffle 3 copies of it into your deck.',
#   '<b>Battlecry:</b> Deal 2 damage to all undamaged enemy minions.',
#   '<b>Taunt</b>\nCosts (1) less for each minion that died this turn.',
#   '<b>Choose One -</b> Transform into a 5/2 minion; or a 2/5 minion.',
#   'Transform into a 5/2 minion.',
#   'Transform into a 2/5 minion.',
#   'Deal $2 damage.\nUnlock your <b>Overloaded</b> Mana Crystals.',
#   "Cards you play this turn don't cause <b>Overload</b>.",
#   '<b>Battlecry:</b> Gain 1-4 Attack. <b>Overload:</b> (1)',
#   'Deal $3 damage.\nIf your hand is empty, draw a card.',
#   '<b>Battlecry:</b> If your hand is empty, gain +3/+3.',
#   '+3/+3',
#   'Deal $1 damage to all minions. If you have 12 or less Health, deal $3 damage instead.',
#   'Whenever this minion takes damage, deal 2 damage to the enemy hero.',
#   'Summon a random friendly minion that died this game.',
#   '<b>Battlecry:</b> The next Dragon you play costs (2) less.',
#   'Your next Dragon costs (2) less.',
#   'Whenever this minion survives damage, summon another Grim Patron.',
#   'Whenever <b>you</b> target this minion with a spell, gain +1/+1.',
#   'Whenever this minion takes damage, summon a 2/1 Whelp.',
#   '<b>Battlecry:</b> If your opponent has 15 or less Health, gain +3/+3.',
#   'Costs (1) less for each minion that died this turn.',
#   '<b>Battlecry:</b> Summon a random 1-Cost minion for your opponent.',
#   '<b>Deathrattle:</b> Replace your hero with Ragnaros, the Firelord.',
#   '<b>Hero Power</b>\nDeal $8 damage to a random enemy.',
#   '<b>Hero Power</b>\nDeal $8 damage to a random enemy. TWICE.',
#   'At the end of your turn, reduce the Cost of cards in your hand by (1).',
#   "<b>Battlecry:</b> If you're holding a Dragon, destroy a <b>Legendary</b> minion.",
#   "<b>Battlecry:</b> Add 2 random spells to your hand <i>(from your opponent's class)</i>.",
#   'Deal $4 damage.',
#   'Whenever you draw a card, put another copy into your hand.',
#   "<b>Battlecry:</b> If you're holding a Dragon, gain +1/+1.",
#   '+1/+1',
#   "<b>Battlecry:</b> If you're holding a Dragon, deal 3 damage.",
#   '[x]  <b>Battlecry:</b> If your deck has  \nno duplicates, your Hero\n Power costs (0) this game.',
#   'Your <b>Hero Power</b> costs (0).',
#   '<b>Freeze</b> an enemy.',
#   'Whenever this attacks a minion and survives, draw\xa0a card.',
#   '<b>Secret:</b> After your opponent plays a minion, give a random minion in your hand +2/+2.',
#   '+2/+2 from Hidden Cache.',
#   'Whenever  you cast a spell, gain +2 Attack.',
#   '[x]<b>Battlecry:</b> Restore 6 Health.\n<b>Overload:</b> (1)',
#   '[x]<b>Taunt</b>\n<b>Battlecry:</b> Give adjacent\n\xa0minions <b>Divine Shield</b>.',
#   '<b>Battlecry:</b> Swap the Attack and Health of a minion.',
#   'Attack and Health have been swapped by Kooky Chemist.',
#   'Whenever you summon a <b>Battlecry</b> minion while this\xa0is in your hand, gain\xa0+1/+1.',
#   'Deal $2 damage to all\xa0minions.',
#   '[x]<b>Battlecry:</b> The next <b>Secret</b>\nyou play this turn costs (0).',
#   '<b>Battlecry</b>: Restore a minion to full Health.',
#   'Deal $5 damage to all characters.',
#   "<b>Deathrattle:</b> Shuffle this minion into your opponent's deck.",
#   '<b>Deathrattle:</b> Restore 4 Health to both players.',
#   'Give all minions in your hand +1/+1.',
#   "+1/+1 from Smuggler's Run.",
#   '<b>Choose One -</b> Gain 10 Armor; or Refresh your Mana Crystals.',
#   'Gain 10 Armor.',
#   'Refresh your Mana Crystals.',
#   'Summon four 1/1 Murlocs.',
#   '<b>Battlecry:</b> Summon a{1} {0} <b>Jade Golem</b>. Give it <b>Taunt</b>.',
#   '<b>Discover</b> a card with\xa0<b>Overload</b>. <b>Overload:</b> (1)',
#   '<b>Battlecry:</b> Summon a 1/1\xa0Cat.',
#   "[x]<b>Deathrattle:</b> Summon a\nnumber of 1/1 Rats equal\n\xa0to this minion's Attack.",
#   '[x]<b>Battlecry:</b> <b>Discover</b> a\nHunter, Paladin, or Warrior\ncard.',
#   "<b>Taunt</b>\n<b>Deathrattle:</b> Shuffle\n'The Storm Guardian' into your deck.",
#   'Has +2 Attack while you have a weapon equipped.',
#   '[x]<b>Battlecry:</b> If you control\na minion with 6 or more\n\xa0Health, draw two cards.',
#   'After this attacks a\nminion, it also hits the enemy hero.',
#   'Give a random Beast in your hand +2/+2.',
#   "+2/+2 from Smuggler's Crate.",
#   "<b>Battlecry:</b> Deal damage equal to this minion's Attack.",
#   '[x]<b>Deathrattle:</b> Give a random\nminion in your hand +2/+2.',
#   '+2/+2 from Shaky Zipgunner.',
#   '[x]After your hero attacks,\nsummon a 1/1 Piranha.',
#   '<b>Battlecry:</b> Give a random Beast in your hand +1/+1.',
#   '+1/+1 from Trogg Beastrager.',
#   "<b>Deathrattle:</b> Deal damage equal to this minion's Attack to all enemy minions.",
#   '<b>Battlecry:</b> If your weapon has at least 3 Attack, gain +4/+4.',
#   '+4/+4.',
#   '[x]<b>Taunt</b>\n<b>Battlecry:</b> Summon a{1}\n{0} <b>Jade Golem</b>.',
#   '[x]<b>Stealth</b>\n   Whenever this attacks and   \nkills a minion, summon 2\n\xa0Murlocs from your deck.',
#   '<b>Choose One -</b> Summon a{1} {0} <b>Jade Golem</b>; or Shuffle 3 copies of this card into your deck.',
#   'Summon a{1} {0} <b>Jade Golem</b>.',
#   'Shuffle 3 Jade Idols into your deck.',
#   'Gain control of an enemy minion with 2 or less Attack until end of turn.',
#   'This minion has switched controllers this turn.',
#   'Restore 12 Health to a friendly character.',
#   "[x]<b>Battlecry:</b> If you're holding a\nDragon, <b>Discover</b> a card in\n\xa0your opponent's deck.",
#   'Whenever this minion is\xa0healed, summon a 2/2\xa0Crystal.',
#   'Destroy a minion and one of your Mana Crystals.',
#   'At the start of your turn, deal 2 damage to this\xa0minion.',
#   '<b>Battlecry:</b> Give your Demons +1/+1.',
#   "[x]Give a minion +3 Attack.\nIf it's a Demon, also\ngive it +3 Health.",
#   'Give your minions +1/+1.',
#   'Gain an empty Mana Crystal for each friendly minion.',
#   '<b>Battlecry:</b> If a friendly minion has 5 or more Attack, gain +2/+2.',
#   '<b>Battlecry:</b> Add a random Potion to your hand.',
#   '<b>Secret:</b> After your opponent plays a minion, transform it into a\n1/1 Sheep.',
#   '[x]<b>Battlecry:</b> If your deck\nhas no duplicates,\n\xa0create a custom spell.',
#   '+2 Health.',
#   '+4 Health.',
#   '+6 Health.',
#   '{0}\n{1}',
#   'Summon a 2/2 Demon.',
#   'Create a 1-Cost spell.',
#   'Create a 5-Cost spell.',
#   'Create a 10-Cost spell.',
#   'Deal $5 damage.',
#   'Gain 7 Armor.',
#   'Deal $4 damage to all minions.',
#   '<b>Freeze</b> 2 random enemy minions.',
#   'Deal $3 damage.',
#   'Summon a 5/5 Demon.',
#   'Transform a random enemy minion into a 1/1 Sheep.',
#   'Draw 2 cards.',
#   'Add 2 random Demons to your hand.',
#   'Give your minions +4 Health.',
#   'Deal $8 damage.',
#   '<b>Freeze</b> 3 random enemy minions.',
#   'Summon an 8/8 Demon.',
#   'Transform all minions into 1/1 Sheep.',
#   'Gain 4 Armor.',
#   'Draw 3 cards.',
#   'Add 3 random Demons to your hand.',
#   'Give your minions +6 Health.',
#   'Deal $6 damage to all minions.',
#   'Summon a friendly minion that died this game.',
#   'Summon 2 friendly minions that died this game.',
#   'Summon 3 friendly minions that died this game.',
#   '<b>Freeze</b> a random enemy minion.',
#   'Give your minions +2 Health.',
#   'Draw a card.',
#   'Add a random Demon to your hand.',
#   'Shoot three missiles at random enemies that deal $3 damage each.',
#   '<b>Battlecry:</b> Give a friendly minion +3 Health.',
#   'Gain 1 Mana Crystal this turn only.',
#   '[x]After your hero attacks,\ngive a random minion in\nyour hand +1/+1.',
#   'Increased stats from Brass Knuckles.',
#   '<b>Stealth</b>. Whenever this attacks and kills a minion, gain <b>Stealth</b>.',
#   '[x]<b>Charge</b>\nAfter you play a Pirate,\nsummon this minion\nfrom your deck.',
#   'At the end of your turn, give all minions in your hand +1/+1.',
#   'Increased stats from Grimestreet Enforcer.',
#   '<b>Battlecry:</b> Give all weapons in your hand and deck +1 Attack.',
#   '+1 Attack from Hobart Grapplehammer.',
#   '[x]<b>Deathrattle:</b> Deal 2 damage\nto the enemy hero.',
#   '<b>Battlecry:</b> Deal 1 damage.',
#   '<b>Battlecry:</b> Summon a 6/6\xa0Ogre.',
#   '<b>Battlecry:</b> <b>Discover</b> a Mage, Priest, or Warlock card.',
#   '[x]<b>Battlecry:</b> Give a random\nMurloc in your hand +1/+1.',
#   '+1/+1 from Grimscale Chum.',
#   '<b>Battlecry:</b> Give your weapon +1 Attack.',
#   '+1 Attack.',
#   '[x]<b>Taunt</b>\nCosts (2) less if your\nopponent has at least\nthree minions.',
#   'At the end of your turn, restore 1 Health to your\xa0hero.',
#   "<b>Battlecry:</b> Remove 1 Durability from your opponent's weapon.",
#   '<b>Battlecry:</b> Enemy minions lose <b>Stealth</b>.',
#   '[x]<b>Battlecry:</b> <b>Silence</b> a minion.',
#   'Whenever a friendly minion dies, gain +1 Attack.',
#   '<b>Battlecry:</b> Restore 2\xa0Health.',
#   '<b>Battlecry:</b> Choose a friendly minion. Shuffle a copy into your deck.',
#   '[x]Give all enemy minions\n-3 Attack this turn only.',
#   '-3 Attack this turn.',
#   '[x]Deal $5 damage to all\nminions except Dragons.',
#   '[x]At the end of your turn,\nadd a random Demon\nto your hand.',
#   '[x]<b>Battlecry:</b> Deal 5 damage\nto an enemy minion.\n<b>Deathrattle:</b> Deal 5 damage\nto your hero.',
#   '<b>Battlecry:</b> Summon 2 copies of this minion.',
#   'Whenever your opponent casts a spell, add a Coin to your hand.',
#   'All targets are chosen randomly.',
#   '<b>Battlecry:</b> Gain +2/+2\nif an enemy is <b>Frozen</b>.',
#   '<b>Battlecry:</b> Choose a friendly minion. Swap it with a minion in your deck.',
#   '<b>Battlecry:</b> Give a random minion in your hand +5/+5.',
#   "+5/+5 from Don Han'Cho.",
#   '[x]<b>Battlecry:</b> If your deck has\nno duplicates, the next\nspell you cast this turn\ncosts (0).',
#   'The next spell you cast this turn costs (0).',
#   '<b>Battlecry:</b> If an enemy minion has <b>Taunt</b>, gain\xa0<b>Charge</b>.',
#   'Deal $2 damage.\n<b>Combo:</b> Summon a{1} {0} <b>Jade Golem</b>.',
#   '<b>Stealth</b>\n<b>Deathrattle:</b> Summon a{1} {0} <b>Jade Golem</b>.',
#   '<b>Combo:</b> Return a friendly minion to your hand.',
#   '<b>Battlecry:</b> Give a <b>Stealthed</b> minion +2/+2.',
#   'Transform all enemy minions into random ones that cost (1) less.',
#   '[x]After this minion attacks\na hero, transform it into a\n\xa0random 6-Cost minion.',
#   '[x]<b>Battlecry:</b> The next Murloc\nyou play this turn costs\n\xa0Health instead of Mana.',
#   'Deal $4 damage. Summon a{1} {0} <b>Jade Golem</b>.',
#   'Summon a{1} {0} <b>Jade Golem</b>. Gain an empty Mana Crystal.',
#   '<b>Battlecry:</b> Summon a{1} {0} <b>Jade\xa0Golem</b>.',
#   'Deal $3 damage to all damaged minions.',
#   '<b>Battlecry:</b> Summon a{1} {0} <b>Jade Golem</b>.\n<b><b>Overload</b>:</b> (1)',
#   '[x]<b>Battlecry:</b> If your deck has\nno duplicates, summon all\n\xa0Demons from your hand.\xa0',
#   '<b>Battlecry:</b> Deal 3 damage to all other characters.',
#   'Give a random <b>Taunt</b> minion in your hand +3/+3.',
#   '+3/+3 from Stolen Goods.',
#   '<b>Battlecry:</b> Give all minions in your hand +1/+1.',
#   '+1/+1 from Grimestreet Outfitter.',
#   'At the end of your turn, give a random minion in your hand +2/+2.',
#   'Increased stats from Grimy Gadgeteer.',
#   '<b>Battlecry:</b> Give a random weapon in your hand +1/+1.',
#   '+1/+1 from Grimestreet Pawnbroker.',
#   '[x]<b>Taunt</b>\nWhenever this minion\ndeals damage, gain\nthat much Armor.',
#   '<b>Deathrattle:</b> If this minion has 2 or more Attack, draw a card.',
#   "Costs (2) less for each <b>Secret</b> you've played this\xa0game.",
#   "[x]<b>Stealth</b>. Whenever this\nattacks, add a random card\nto your hand <i>(from your\nopponent's class).</i>",
#   '[x]<b>Taunt</b>\n<b>Battlecry:</b> Your opponent\nsummons a random minion\nfrom their hand.',
#   '<b>Secret:</b> When a friendly minion dies, return it to your hand.',
#   "<b>Taunt</b>. <b>Battlecry:</b> Draw cards until you draw one that isn't a Dragon.",
#   'After you cast a spell, refresh your Hero Power.',
#   'Whenever this attacks, both players draw until they have 3 cards.',
#   "[x]<b>Battlecry:</b> If your opponent's\nhand is empty, gain <b>Charge</b>.",
#   '<b>Battlecry:</b> If your opponent has 6 or more cards in hand, gain <b>Charge</b>.',
#   'Draw 2 cards. Minions drawn cost (2) less.',
#   '[x]<b>Divine Shield</b>. <b>Taunt</b>.\nDamage dealt by this minion\nalso heals your hero.',
#   '<b>Battlecry:</b> Give a friendly Beast +2/+2.',
#   'Whenever your opponent draws a card, gain +1/+1.',
#   '<b>Battlecry:</b> <b>Discover</b> a Druid, Rogue, or Shaman card.',
#   '<b>Battlecry:</b> Give a random minion in your hand +1/+1.',
#   '+1/+1 from Grimestreet Smuggler.',
#   '<b>Battlecry:</b> <b>Silence</b> a minion with <b>Deathrattle</b>.',
#   'Whenever you summon a minion, deal 5 damage to\xa0your Hero.',
# ...
#   "The fourth one fell off in a tragic accident.  They don't talk about it.",
#   "He's very good at retrieving artifacts.  From other people's museums.",
#   "It's perfectly safe as long as you remember to put in air holes.",
#   "Harrison Jones was disappointed that he didn't get to be part of the League of Explorers, but his hat did.",
#   "Don't blink!  Don't turn your back, don't look away, and DON'T BLINK.",
#   'Warning: Do not expose to direct sunlight.',
#   "MOM! DAD! DON'T TOUCH IT! IT'S EVIL!!!!!!",
#   "Everyfin is cool when you're part of a murloc team!",
#   "Was petrified when it found out it didn't make the cut for Azerothian Idol.",
#   "The Reliquary considers itself the equal of the League of Explorers.  The League of Explorers doesn't.",
#   'The Curse is that you have to listen to "MMMBop" on repeat.',
#   'Try putting it on.  Wait, let me get my camera.',
#   'This is the reason that Demons never really become friends with Warlocks.',
#   'He just wants people to see his vacation photos.',
#   'Is the sky falling?  Yes.  Yes it is.',
#   'Go ahead, carve your initials in him.',
#   "He is the weakest of the four Elemental Lords.  And the other three don't let him forget it.",
#   "The Kor'kron are the elite forces of Garrosh Hellscream. Let's just say you don't want to run into these guys while wearing a blue tabard.",
#   "These wyrms feed on arcane energies, and while they are generally considered a nuisance rather than a real threat, you really shouldn't leave them alone with a bucket of mana.",
#   'She\'s actually a male tauren.  People don\'t call him "Master of Disguise" for nothing.',
#   'Pirates and Parrots go together like Virmen and Carrots.',
#   "Murloc.  It's what's for dinner.",
#   '"I only plunder on days that end in \'y\'."',
#   'Ambitious Knife Jugglers sometimes graduate to Bomb Jugglers.    They never last long enough to make it onto a card though.',
#   'BOOM BABY BOOM!  BAD IS GOOD!  DOWN WITH GOVERNMENT!',
#   "He's almost been right so many times. He was <i>sure</i> it was coming during the Cataclysm.",
#   '"Yarrrr" is a pirate word that means "Greetings, milord."',
#   "Adorable.  Immune to Magic.  Doesn't pee on the rug.  The perfect pet!",
#   "He was <i>this close</i> to piloting a massive juggernaut into Stormwind Harbor. If it weren't for those pesky kids!",
#   'Every pirate uses the same four digits to access Automated Gold Dispensers.  It\'s called the "Pirate\'s Code".',
#   "If you don't pay attention, you may be turned into a pig.  And then you get your name on the board.",
#   "When he saves enough plunder, he's going to commission an enormous captain's hat.  He has hat envy.",
#   '"I\'m gonna light you up, sweetcheeks!"',
#   'Once a noble dragon known as Neltharion, Deathwing lost his mind and shattered Azeroth before finally being defeated.  Daddy issues?',
#   "You could summon Misha, Leokk, or Huffer!  Huffer is more trouble than he's worth.",
#   '"Shout! Shout! Let it all out!" - Advice to warriors-in-training',
#   'He\'s currently trying to craft a "flail-axe", but all the other swordsmiths say it can\'t be done.',
#   'He\'s Gruul "the Dragonkiller".  He just wanted to cuddle them… he never meant to…',
#   "Hogger is super powerful. If you kill him, it's because he <i>let</i> you.",
#   'This Kodo is so big that he can stampede by <i>himself</i>.',
#   'Nobody expects the Vilefin Inquisition!',
#   'Golce and Dabbana have a new line of Earth Totems available at vendors everywhere this holiday season.',
#   "He's on fire! Boomshakalaka!",
#   'Just try to avoid eye contact.',
#   'So you say you want an evolution. Well, you know. We all want to change the board.',
#   "Just can't resist the opportunity to hang around with a bunch of totems.",
#   "Stop! It's Twilight Hammer time.",
#   "That's right. Garrosh just slapped you to death with a tentacle.",
#   'If your hero doesn\'t attack, it\'s just "Silithid Loner".',
#   "When he's working out, he binds all that rage back into a ponytail.",
#   'Always manages to mention "Back when I was creating the World Tree…" in EVERY conversation. Sheesh! Enough already.',
#   'The best part is the look on their face when you jump out of the cake! Err… corpse.',
#   "Let's be honest. One option is a lot ragier than the other.",
#   "Y'Shaarj had three sons: Mark, Theodore, and Chris.",
#   "This Ancient was banned from the local tavern after tucking a 'Dr. Boom' up its sleeve.",
#   "The mastiff giggles if you don't hit any ducks.",
#   'He has a poor understanding of the law of diminishing returns.',
#   "Don't stop believing there's something below.",
#   "Aren't Thistles prickly?  Why would you drink them? I don't get Rogues.",
#   "It's basically your own fault if you go around drinking weird green potions handed out by creepy mantid dudes.",
#   "What's cooler than being cool?",
#   'You no take tentacle!',
#   'Make sure you summon a Twilight Marshmallowcaller too! Mmmm Mmm Mmm!!',
#   "He prefers that you refer to him by his nickname: 'Frostwaker.'",
#   'WARNING: This flame is not to be used unless you are a licensed acolyte of the Old Gods.',
#   'Yogg-Saron always likes to complain about how he has too many servants and there are too many mouths to feed.',
#   "What's in there? I bet it's cookie recipes!",
#   "Because you're wrapped in a protective layer of… tentacles?",
#   'First she separates them from the lights, washes them in cold water, and hang-dries.',
#   'It\'s more succinct than "Shadow Word: Suck Into Vortex."',
#   'But the minion arrives covered in goo.',
#   'People often think that Darkspeaker is the arch nemesis of Lightspeaker, but that title actually belongs to Heavyspeaker.',
#   'For when your Auchenai Soulpriests call in sick.',
#   'Do NOT be late with your overdue fines.',
#   'Democracy in action!',
#   "Actually, C'Thun gives his full support for this ritual.",
#   'Most citizens of Darkshire wear those surgical masks to prevent spreading Madness to tourists.',
#   'SEE YA DARKNESS!',
#   'That\'s short for "Anomnomnomnomalus".',
#   "Even after all this time, Gul'dan still makes Cho'gall go get donuts and coffee.",
#   'Pro tip: DO NOT BOGART THE BANANAS.',
#   "It's like being able to play with THREE angry chickens!",
#   'Do they make decisions based on age? "I\'m two minutes older therefore we burn this village."',
#   'Has not been able to get "Under the Sea" out of his head for like FIVE THOUSAND YEARS.',
#   'I spell your doom... Y-O-U-R D-O-O-M!',
#   'It’s a self-reducing prophecy.',
#   "Rejected names: Forty-Foot Faceless, Big ol' No-face, Huge Creature Sans Face, Teddy.",
#   'Often wonders what path his life might have taken if he wasn\'t named, you know, "Eldritch Horror".',
#   '"Annoyinger-o-Tron" was just too unwieldy. And accurate.',
#   'Not so much "corrupted" as "has terrible aim".',
#   'But goes by "Ravishing Ghoul" when he hits the club.',
#   'I berserk, therefore I am.',
#   "Because EVERYDAY is the Day of the Tentacle of N'zoth.",
#   'They say that "grotesque is in the eye of the beholder," but that\'s just because they\'ve never seen a Grotesque Dragonhawk. Yikes!',
#   "He's tried other things, but bog sidling, bog ambling, and bog trundling just aren't as effective as bog creeping.",
#   'Bile actually makes for surprisingly sturdy fins.',
#   'Ok, Initiate. You need to settle down and do your job. In this case, that means die so someone else can get a minor buff.',
#   "For seers, it's very handy to have your crystal ball hanging right in front of your face.",
#   'C’Thun’s recruiting pitch involves cookies, which is why it’s the most popular Old God.',
#   'Add two cups of Blood of the Ancient One to one cup of lemon juice. Add just a dash of sugar and stir. Delicious!',
#   '"What is that thing?!" "I\'m not sure, but it seems to be sort of Y\'sera shaped."',
#   "It's like a backstab, only from the front. And with two more stabs.",
#   "He'll always be our first.",
#   'Amberweaving is a specialty course at the local trade school.',
#   'They\'re just normal wisps, actually. The "Of the Old Gods" bit is just marketing.',
#   "No one's quite sure why it's forbidden. And yes, that should make you nervous.",
#   'Really feels good about himself and is in a much better place now. But… he sure does miss piloting those shredders.',
#   '"Hey.... Is that Mire for sale?" \n"No.  I\'m keeping it."',
#   'WARNING: DO NOT TOUCH THE PURPLE BALL OF LIGHTNING',
#   'They never get the recognition they deserve.',
#   'Hallazeals all your dallazamage.',
#   '"Hello. Misha, Leokk and Huffer aren\'t here right now, but if you leave a message we\'ll get back to you right away." BEEP.',
#   'A little flea powder will fix that right up.',
#   'He thought the set was called "Flippers of the Old Cods" and hungrily volunteered to be in it.  He is definitely going to get his hearing checked.',
#   "Garrosh's best buddy. It's true. Look it up.",
#   '"Don\'t worry about me… I\'ll just be here... under these tentacles."',
#   'As far as blades go, this one is pretty great in the motivation department.',
#   'Every year a few paladins get disqualified from the Westfall weight lifting championship for using Divine Strength.',
#   'What happens when you try and corrupt a corrupted firelord? DOUBLE NEGATIVE, INSECT!',
#   'The secret ingredient: liquified funnel cake.',
#   'We ran out of space for "DOOOOOOOOOOOM!!!!!"',
#   ...],
#  [nan, 'BEAST', 'DRAGON', 'DEMON', 'PIRATE', 'TOTEM', 'MURLOC', 'MECHANICAL'],
#  [nan,
#   'Unlocked in Hidden Laboratory, in the Blackrock Mountain adventure.',
#   'Unlocked in Blackwing Lair, in the Blackrock Mountain adventure.',
#   'Unlocked in Blackrock Depths, in the Blackrock Mountain adventure.',
#   'Unlocked in Blackrock Spire, in the Blackrock Mountain adventure.',
#   'Unlocked in Molten Core, in the Blackrock Mountain adventure.',
#   'Unlocked at Level 6.',
#   'Unlocked at Level 10.',
#   'Unlocked at Level 1.',
#   'Unlocked at Level 4.',
#   'Unlocked at Level 8.',
#   'Unlocked at Level 2.',
#   'Unlocked when you have all the Murlocs from the Classic Set.',
#   'Unlocked in The Construct Quarter, in the Naxxramas adventure.',
#   'Unlocked in The Arachnid Quarter, in the Naxxramas adventure.',
#   'Unlocked in Frostwyrm Lair, in the Naxxramas adventure.',
#   'Unlocked in The Military Quarter, in the Naxxramas adventure.',
#   'Unlocked in The Plague Quarter, in the Naxxramas adventure.',
#   'Unlocked in the Menagerie, in One Night in Karazhan.',
#   'Unlocked in the Opera, in One Night in Karazhan.',
#   'Unlocked in the Parlor, in One Night in Karazhan.',
#   'Unlocked in the Spire, in One Night in Karazhan.',
#   'Unlocked in the Prologue, in One Night in Karazhan.',
#   'Unlocked in The Ruined City, in the League of Explorers adventure.',
#   'Unlocked by starting the League of Explorers adventure.',
#   'Unlocked in Uldaman, in the League of Explorers adventure.',
#   'Unlocked in the Hall of Explorers, in the League of Explorers adventure.',
#   'Unlocked in the Temple of Orsis, in the League of Explorers adventure.',
#   'Unlocked when you have all the Pirates from the Classic Set.',
#   'Unlocked when opening a Whispers of the Old Gods pack.'],
#  [nan,
#   'Crafting unlocked in Hidden Laboratory, in the Blackrock Mountain adventure.',
#   'Crafting unlocked in Blackwing Lair, in the Blackrock Mountain adventure.',
#   'Crafting unlocked in Blackrock Depths, in the Blackrock Mountain adventure.',
#   'Crafting unlocked in Blackrock Spire, in the Blackrock Mountain adventure.',
#   'Crafting unlocked in Molten Core, in the Blackrock Mountain adventure.',
#   'Unlocked at Paladin Level 57.',
#   'Unlocked at Level 45.',
#   'Unlocked at Level 49.',
#   'Unlocked at Level 23.',
#   'Unlocked at Level 32.',
#   'Unlocked at Level 47.',
#   'Unlocked at Level 15.',
#   'Unlocked at Level 40.',
#   'Unlocked at Level 28.',
#   'Unlocked at Level 43.',
#   'Unlocked at Level 36.',
#   'Unlocked at Level 44.',
#   'Unlocked at Level 51.',
#   'Unlocked at Shaman Level 51.',
#   'Unlocked at Druid Level 51.',
#   'Unlocked at Druid Level 55.',
#   'Unlocked at Shaman Level 57.',
#   'Unlocked at Warrior Level 57.',
#   'Unlocked at Warrior Level 59.',
#   'Unlocked at Hunter Level 59.',
#   'Unlocked at Warrior Level 53.',
#   'Unlocked at Paladin Level 55.',
#   'Unlocked at Mage Level 55.',
#   'Unlocked at Warlock Level 59.',
#   'Unlocked at Priest Level 57.',
#   'Unlocked at Paladin Level 51.',
#   'Unlocked at Mage Level 57.',
#   'Unlocked at Priest Level 59.',
#   'Unlocked at Priest Level 51.',
#   'Unlocked at Hunter Level 53.',
#   'Unlocked at Hunter Level 57.',
#   'Unlocked at Paladin Level 53.',
#   'Unlocked at Rogue Level 59.',
#   'Unlocked at Warrior Level 55.',
#   'Unlocked at Rogue Level 51.',
#   'Unlocked at Shaman Level 55.',
#   'Unlocked at Druid Level 57.',
#   'Unlocked at Hunter Level 55.',
#   'Unlocked at Warlock Level 55.',
#   'Unlocked at Warlock Level 51.',
#   'Unlocked at Hunter Level 51.',
#   'Unlocked at Shaman Level 59.',
#   'Unlocked at Paladin Level 59.',
#   'Unlocked at Shaman Level 53.',
#   'Unlocked at Priest Level 55.',
#   'Unlocked at Rogue Level 55.',
#   'Unlocked at Druid Level 59.',
#   'Unlocked at Priest Level 53.',
#   'Unlocked at Mage Level 53.',
#   'Unlocked when you have all the Golden Murlocs from the Expert and Basic Sets.',
#   'Unlocked at Rogue Level 57.',
#   'This was rewarded to players who helped test the Store during the Beta.',
#   'Unlocked at Warlock Level 57.',
#   'Unlocked at Rogue Level 53.',
#   'Unlocked at Warlock Level 53.',
#   'Unlocked at Mage Level 59.',
#   'Unlocked at Druid Level 53.',
#   'Crafting unlocked in The Construct Quarter, in the Naxxramas adventure.',
#   'Crafting unlocked in The Arachnid Quarter, in the Naxxramas adventure.',
#   'Crafting unlocked in Frostwyrm Lair, in the Naxxramas adventure.',
#   'Crafting unlocked in The Military Quarter, in the Naxxramas adventure.',
#   'Crafting unlocked in The Plague Quarter, in the Naxxramas adventure.',
#   'Crafting unlocked in the Menagerie, in One Night in Karazhan.',
#   'Crafting unlocked in the Opera, in One Night in Karazhan.',
#   'Crafting unlocked in the Parlor, in One Night in Karazhan.',
#   'Crafting unlocked in the Spire, in One Night in Karazhan.',
#   'Crafting unlocked in the Prologue, in One Night in Karazhan.',
#   'Crafting unlocked in The Ruined City, in the League of Explorers adventure.',
#   'Can be crafted after starting the League of Explorers adventure.',
#   'Crafting unlocked in Uldaman, in the League of Explorers adventure.',
#   'Crafting unlocked in the Hall of Explorers, in the League of Explorers adventure.',
#   'Crafting unlocked in the Temple of Orsis, in the League of Explorers adventure.',
#   'Unlocked when you have all the Golden Pirates from the Expert Set.',
#   'Crafting unlocked after opening a Whispers of the Old Gods pack.',
#   'Awarded at BlizzCon 2013.'],
#  [nan,
#   'Deal 1 damage.',
#   'Grant <b>Immune</b> this turn.',
#   'Grant <b>Taunt</b>.',
#   'Give +2 Attack.',
#   'Give +1/+1.',
#   'Deal 4 damage.',
#   '<b>Silence</b> a Demon.',
#   'Deal 6 damage.',
#   'Destroy a Legend.',
#   'Deal 3 damage.',
#   'Restore 2 Health.',
#   'Restore 3 Health.',
#   'Deal 2 damage.',
#   'Grant +2 Attack.',
#   '<b>Silence</b> a minion.',
#   'Give a Beast +2/+2 and Taunt.',
#   'Destroy a minion with Taunt.',
#   'Destroy a minion with an Attack of 7 or more.',
#   'Return a minion to your hand.',
#   'Swap Attack and Health of a minion.',
#   'Transform a minion into a 5/5 or a 1/1 at random.',
#   'Steal a minion that has 2 or less Attack.',
#   'Deal 1 damage.  Combo: 2 instead.',
#   'Freeze a character.',
#   'Give <b>Divine Shield</b>.',
#   'Change Attack to 1.',
#   'Set Health to 15.',
#   'Become a copy of a minion.',
#   'Give <b>Windfury</b>.',
#   'Deal 1 damage and grant +2 Attack.',
#   'Give +3 Health.',
#   'Give -2 Attack this turn.',
#   'Swap Health.',
#   'Give +2/+2.',
#   'Give a Mech +4 Health.',
#   'Transform!',
#   'Destroy a Beast.',
#   'Give <b>Spell Damage +2</b>.',
#   'Change to 3/3.',
#   'Return a minion to hand.',
#   'Give <b>Stealth</b>.'],
#  [nan, 'ALLIANCE', 'HORDE'],
#  [nan, 3.0, 4.0, 2.0, 5.0, 6.0, 8.0, 1.0],
#  ['CRAFTING_NORMAL',
#   'CRAFTING_GOLDEN',
#   'DISENCHANT_NORMAL',
#   'DISENCHANT_GOLDEN',
#   nan],
#  [40.0, 400.0, 5.0, 50.0, 100.0, 800.0, 20.0, 1600.0, nan, 3200.0]]

# %%
# Out:
# ['player_class',
#  'type',
#  'name',
#  'set',
#  'text',
#  'cost',
#  'attack',
#  'health',
#  'rarity',
#  'collectible',
#  'flavor',
#  'race',
#  'how_to_earn',
#  'how_to_earn_golden',
#  'targeting_arrow_text',
#  'faction',
#  'durability',
#  'action',
#  'cost_dust']
