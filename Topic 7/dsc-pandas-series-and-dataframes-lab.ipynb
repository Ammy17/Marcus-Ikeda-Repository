# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
# Rename all the columns to lower case
column_names = [col.strip() for col in df.columns]
lower_names = []
for name in column_names :
    lower_names.append(name.lower())
df.columns = lower_names
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries    exits
# ...

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
df.set_index('linename')
# Out:
#             c/a  unit       scp        station division        date      time  \
# linename
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# ...         ...   ...       ...            ...      ...         ...       ...
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  21:00:00
#
# ...

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df.reset_index()
# Out:
#          index    c/a  unit       scp        station linename division  \
# 0            0   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1            1   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2            2   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3            3   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4            4   A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...        ...    ...   ...       ...            ...      ...      ...
# 197620  197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197621  197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197622  197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197623  197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197624  197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#               date      time     desc  entries    exits
# 0       08/25/2018  00:00:00  REGULAR  6736067  2283184
# ...

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
lines = df.linename.tolist()
number = []

for item in lines :
    item = len(item)
    number.append(item)
    
df['Num_Lines'] = number
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries    exits  Num_Lines
# ...

# %% [markdown]
# Write a function to clean column names:

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = []
    for name in col_name :
        name = name.strip()
        name = name.lower()
        cleaned.append(name)
    return cleaned

# %%
# Use the above function to clean the column names
col_name = df.columns
df.columns = clean(col_name)

# %%
# Check to ensure the column names were cleaned
df.columns
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries    exits  num_lines
# ...

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
df['date'] = pd.to_datetime(df['date'], format = '%m/%d/%Y')

# Add a new column 'day_of_week' that represents the day of the week 
df['day_of_week'] = df['date'].dt.day_name()
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   c/a          197625 non-null  object
#  1   unit         197625 non-null  object
#  2   scp          197625 non-null  object
#  3   station      197625 non-null  object
#  4   linename     197625 non-null  object
#  5   division     197625 non-null  object
#  6   date         197625 non-null  datetime64[ns]
#  7   time         197625 non-null  object
#  8   desc         197625 non-null  object
#  9   entries      197625 non-null  int64
#  10  exits        197625 non-null  int64
#  11  num_lines    197625 non-null  int64
#  12  day_of_week  197625 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 19.6+ MB

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum()
grouped.plot(kind='barh')
plt.show()
# Out:
# /tmp/ipykernel_19790/1272281373.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = df.groupby('day_of_week').sum()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped = df.reset_index()

# Print the first five rows of grouped
grouped.head()
# Out:
#    index   c/a  unit       scp station linename division       date      time  \
# 0      0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1      1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
# 2      2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  08:00:00
# 3      3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  12:00:00
# 4      4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  num_lines day_of_week
# 0  REGULAR  6736067  2283184          7    Saturday
# 1  REGULAR  6736087  2283188          7    Saturday
# 2  REGULAR  6736105  2283229          7    Saturday
# 3  REGULAR  6736180  2283314          7    Saturday
# 4  REGULAR  6736349  2283384          7    Saturday

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {'Monday':False, 'Tuesday':False, 'Wednesday':False, 'Thursday':False, 'Friday':False, 'Saturday':True, 'Sunday':True}



# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map

grouped['is_weekend'] = grouped['day_of_week'].map(weekend_map)
grouped

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').sum()
wkend[['entries', 'exits']].plot(kind='barh')
plt.show()

# %%
grouped['entries', 'exits'].plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/saturncloud/envs/saturn/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/saturncloud/envs/saturn/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/saturncloud/envs/saturn/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('entries', 'exits')
#
# ...

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
df = df.drop(['c/a', 'scp'], axis = 1)
df.head(2)

# %%
df.loc[df['station'].str.contains('RIT-ROOSEVELT')]

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here 
# Does the chart even have a real scale? the data is implying that there are over 5 billion entries on weekdays and
# 2 billion entires on weekends for about 1 billion per day the chart doesnt show that sunday has a higher amount of entries
# than each other data. Why are entries significantly higher than exits? Why are there so many entries with the same results

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
